# %%
# !pip install jsonpath_ng
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting jsonpath_ng
#   Downloading jsonpath_ng-1.5.3-py3-none-any.whl (29 kB)
# Collecting ply (from jsonpath_ng)
#   Downloading ply-3.11-py2.py3-none-any.whl (49 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.6/49.6 kB 3.1 MB/s eta 0:00:00
# Requirement already satisfied: decorator in /usr/local/lib/python3.10/dist-packages (from jsonpath_ng) (4.4.2)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from jsonpath_ng) (1.16.0)
# Installing collected packages: ply, jsonpath_ng
# Successfully installed jsonpath_ng-1.5.3 ply-3.11

# %%
import os
import csv
import json
import numpy as np 
import pandas as pd 
import sqlite3
import re
import datetime
import functools as ft
import matplotlib.pyplot as plt
from abc import ABC, abstractmethod
from jsonpath_ng import parse
from enum import Enum
# %matplotlib inline

# %% [markdown]
# # Source to Target Mapping - OOP Approach for Single Table

# %% [markdown]
# ### Data

# %%
with open("sales_data.csv", "r", encoding="utf-8-sig") as file:
    data = list(csv.DictReader(file))
    for item in data:
        item["InvoiceNo"] =str(item["InvoiceNo"])
        item["Quantity"] =str(item["Quantity"])
data[:3]
# Out:
# [{'InvoiceNo': '358640',
#   'StockCode': '85123A',
#   'Quantity': '6',
#   'InvoiceDate': '03/01/2015 00:00',
#   'CustomerID': '17850',
#   'Country': 'United Kingdom'},
#  {'InvoiceNo': '386946',
#   'StockCode': '71053',
#   'Quantity': '6',
#   'InvoiceDate': '07/03/2010 00:00',
#   'CustomerID': '17850',
#   'Country': 'United Kingdom'},
#  {'InvoiceNo': '378650',
#   'StockCode': '84406B',
#   'Quantity': '8',
#   'InvoiceDate': '05/05/2014 00:00',
#   'CustomerID': '17850',
#   'Country': 'United Kingdom'}]

# %% [markdown]
# ###  Abstract Base Calss (ABC) for mutual methods

# %%
class Interface(ABC):

    @abstractmethod
    def get_data_by_field(self, field_name):
        """Fetch the data by given feild name """

    @abstractmethod
    def get_data_by_id(self, id):
        """Fetch the data by given ID  """

    @abstractmethod
    def get(self):
        """Fetch all data """

# %% [markdown]
# ### Transform Operations
# inherithed from Enum - class that automatic enumrate the variables

# %%
class TransformMask(Enum):
    CLEAN_STRING = ".strip()" 
    #date format to retrive only date without time
    DATE_FORMAT = ".split()[0]"

# %% [markdown]
# ### Database Class - Define Common Properties for Source, Target, Mapping

# %%
class Database:
    def __init__(self):
        self.db = {
            "source": [],
            "destination": [],
            "transform": [],
            "mapping": []
        }
        #add_source
        self.add_source(1,"InvoiceNo","$.InvoiceNo","str",True)
        self.add_source(2,"Quantity","$.Quantity","str",True)
        self.add_source(3,"InvoiceDate","$.InvoiceDate","str",False)

        #add_transform
        self.add_transform(1,'CLEAN_STRING')
        self.add_transform(2,'DATE_FORMAT')


        #add_destination
        self.add_destination(1,"invoice_id","invoice_id","str","n/a")
        self.add_destination(2,"quantity","quantity","int","0")
        self.add_destination(3,"invoice_dtm","invoice_dtm","str","01/01/1900")

        #add_mapping
        self.add_mapping(1,1,1,1)
        self.add_mapping(2,2,2)
        self.add_mapping(3,3,3,2)

    def add_source(self,id,source_field_name,source_field_mapping,source_field_type,is_required):
      if not isinstance(is_required, bool):
        print("Error. Please enter if required.")
      else:
        source = {
            "id": id,
            "source_field_name": source_field_name,
            "source_field_mapping": source_field_mapping,
            "source_field_type": source_field_type,
            "is_required": is_required
        }
        self.db["source"].append(source)

    def add_transform(self,id,transform_mask):
      transform={
          "id": id,
          "transform_mask": transform_mask
      }
      self.db["transform"].append(transform)    
        
    def add_destination(self,id,destination_field_name,destination_field_mapping,destination_field_type,default_value):
        destination = {
              "id": id,
              "destination_field_name": destination_field_name,
              "destination_field_mapping": destination_field_mapping,
              "destination_field_type": destination_field_type,
              "default_value": default_value
          }
        self.db["destination"].append(destination)

    def add_mapping(self,id,mapping_source,mapping_destination,mapping_transform=None):
      if mapping_transform is not None:
        mapping={
          "id": id,
          "mapping_source": mapping_source,
          "mapping_destination": mapping_destination,
          "mapping_transform": mapping_transform
        }
      else:
        mapping={
          "id": id,
          "mapping_source": mapping_source,
          "mapping_destination": mapping_destination
          }
      self.db["mapping"].append(mapping)

    @property 
    def get_data_source_target_mapping(self):
        return self.db

# %% [markdown]
# ### Source class
#
# Inherited from Interface for the common methods and from Database for common variables

# %%
class Source(Interface, Database):
    def __init__(self):
        Database.__init__(self)

    # should be implemented - inherited from Interface
    def get_data_by_field(self, field_name):
        data = self.get
        for item in data:
            for key, value in item.items():
                if key == field_name:
                    return item
        return None

    @property
    def get(self):
        return self.get_data_source_target_mapping.get("source")

    def get_data_by_id(self, id):
        self.id = id
        data = self.get
        for x in data:
            if x.get("id") == self.id:
                return x
        return None

# %% [markdown]
# ### Target class
#
# Inherited from Interface for the common methods and from Database for common variables

# %%
class Target(Interface, Database):

    def __init__(self):
        Database.__init__(self)

    # should be implemented - inherited from Interface
    def get_data_by_field(self, field_name):
        data = self.get
        for item in data:
            for key, value in item.items():
                if key == field_name:
                    return item
        return None

    @property
    def get(self):
        return self.get_data_source_target_mapping.get("destination")

    def get_data_by_id(self, id):
        self.id = id
        data = self.get
        for x in data:
            if x.get("id").__str__() == self.id.__str__():
                return x
        return None

# %% [markdown]
# ### Transform Class
#
# Inherited from Interface for the common methods and from Database for common variables

# %%
class Transform(Interface, Database):

    def __init__(self):
        Database.__init__(self)

    # should be implemented - inherited from Interface
    def get_data_by_field(self, field_name):
        data = self.get
        for item in data:
            for key, value in item.items():
                if key == field_name:
                    return item
        return None

    @property
    def get(self):
        return self.get_data_source_target_mapping.get("transform", [])

    def get_data_by_id(self, id):
        self.id = id
        data = self.get
        for x in data:
            if x.get("id").__str__() == self.id.__str__():
                return x
        return None

# %% [markdown]
# ### Mapping class
#
# Inherited from Interface for the common methods and from Database for common variables

# %%
class Mappings(Interface, Database):

    def __init__(self):
        Database.__init__(self)

    @property
    def get(self):
        return self.get_data_source_target_mapping.get("mapping")

    def get_data_by_id(self, id):
        self.id = id
        data = self.get
        for x in data:
            if x.get("id").__str__() == self.id.__str__():
                return x
        return None

    def get_data_by_field(self, field_name):
        return None

# %% [markdown]
# ### Format Class - JSON
#
# Search the source data value inside a JSON file

# %%
class JsonQuery:
    def __init__(self, json_path, json_data):
        self.json_path = json_path
        self.json_data = json_data

    def get(self):
        jsonpath_expression = parse(self.json_path)
        match = jsonpath_expression.find(self.json_data)
        source_data_value = match[0].value
        return source_data_value

# %% [markdown]
# ### Combine it All - STTM

# %%
class STTM:
    def __init__(self, input_json):
        self.input_json = input_json
        self.mapping_instance = Mappings()
        self.source_instance = Source()
        self.destination_instance = Target()
        self.transform_instance = Transform()
        self.look_up_mask = {i.name: i.value for i in TransformMask}
        self.json_data_transformed = {}

    def _get_mapping_data(self):
        return self.mapping_instance.get

    def _get_mapping_source_data(self):
        return self.source_instance.get

    def get_transformed_data(self):

        for mappings in self._get_mapping_data():

            """fetch the source mapping """
            mapping_source_id = mappings.get("mapping_source")
            mapping_destination_id = mappings.get("mapping_destination")
            mapping_transform_id = mappings.get("mapping_transform")

            mapping_source_data = self.source_instance.get_data_by_id(id=mapping_source_id)
            transform_data = self.transform_instance.get_data_by_id(id=mapping_transform_id)

            """Fetch Source  field Name"""
            source_field_name = mapping_source_data.get("source_field_name")

            """if field given is not present incoming json """
            if source_field_name not in self.input_json.keys():
                if mapping_source_data.get("is_required"):
                    raise Exception(
                        "Alert ! Field {} is not present in JSON please FIX mappings ".format(source_field_name))
                else:
                    pass

            else:
                source_data_value = JsonQuery(
                    json_path=mapping_source_data.get("source_field_mapping"),
                    json_data=self.input_json
                ).get()

                """check the data type for source if matches with what we have """
                if mapping_source_data.get("source_field_type") != type(source_data_value).__name__:
                    if source_data_value is not None:
                        _message = (
                            "Alert ! Source Field :{} Datatype has changed from {} to {} ".format(source_field_name,
                                                                                                  mapping_source_data.get(
                                                                                                      "source_field_type"),
                                                                                                  type(
                                                                                                      source_data_value).__name__))
                        print(_message)
                        raise Exception(_message)

                """Query and fetch the Destination | target """
                destination_mappings_json_object = self.destination_instance.get_data_by_id(
                    id=mappings.get("mapping_destination"))
               # print(mappings.get("mapping_destination"))
                destination_field_name = destination_mappings_json_object.get("destination_field_name")
                destination_field_type = destination_mappings_json_object.get("destination_field_type")

                dtypes = [str, float, list, int, set, dict]

                for dtype in dtypes:

                    """Datatype Conversion """
                    if destination_field_type == str(dtype.__name__):

                        """is source is none insert default value"""
                        if source_data_value is None:
                            self.json_data_transformed[destination_field_name] = dtype.__call__(
                                destination_mappings_json_object.get("default_value")
                            )

                        else:
                            """check if you have items to transform"""
                            if transform_data is not None:
                                """ check for invalid mask name """
                                if transform_data.get("transform_mask") not in list(self.look_up_mask.keys()):
                                    raise Exception(
                                        f"Specified Transform {transform_data.get('transform_mask')} is not available please select from following Options :{list(self.look_up_mask.keys())}")
                                else:
                                    mask_apply = self.look_up_mask.get(transform_data.get("transform_mask"))
                                    converted_dtype = dtype.__call__(source_data_value)
                                    mask = f'converted_dtype{mask_apply}'
                                    curated_value = eval(mask)
                                    self.json_data_transformed[destination_field_name] = curated_value

                            else:
                                self.json_data_transformed[destination_field_name] = dtype.__call__(source_data_value)

        return self.json_data_transformed

# %%
transformed_data = []
for item in data:
    helper = STTM(input_json=item)
    response = helper.get_transformed_data()
    transformed_data.append(response)
    print(response)
# Out:
# {'invoice_id': '358640', 'quantity': 6, 'invoice_dtm': '03/01/2015'}
# {'invoice_id': '386946', 'quantity': 6, 'invoice_dtm': '07/03/2010'}
# {'invoice_id': '378650', 'quantity': 8, 'invoice_dtm': '05/05/2014'}
# {'invoice_id': '70847', 'quantity': 6, 'invoice_dtm': '18/05/2021'}
# {'invoice_id': '127544', 'quantity': 6, 'invoice_dtm': '22/10/2013'}
# {'invoice_id': '206408', 'quantity': 2, 'invoice_dtm': '10/04/2017'}
# {'invoice_id': '429117', 'quantity': 6, 'invoice_dtm': '11/04/2016'}
# {'invoice_id': '409366', 'quantity': 6, 'invoice_dtm': '22/04/2022'}
# {'invoice_id': '181714', 'quantity': 6, 'invoice_dtm': '15/06/2014'}
# {'invoice_id': '405780', 'quantity': 32, 'invoice_dtm': '06/05/2022'}
# {'invoice_id': '418234', 'quantity': 6, 'invoice_dtm': '17/10/2019'}
# {'invoice_id': '381824', 'quantity': 6, 'invoice_dtm': '05/05/2017'}
# {'invoice_id': '322100', 'quantity': 8, 'invoice_dtm': '03/01/2017'}
# {'invoice_id': '234784', 'quantity': 6, 'invoice_dtm': '01/11/2017'}
# {'invoice_id': '9162', 'quantity': 6, 'invoice_dtm': '20/11/2012'}
# {'invoice_id': '355859', 'quantity': 3, 'invoice_dtm': '05/05/2014'}
# {'invoice_id': '394121', 'quantity': 2, 'invoice_dtm': '25/01/2017'}
# {'invoice_id': '9810', 'quantity': 3, 'invoice_dtm': '20/03/2012'}
# {'invoice_id': '473917', 'quantity': 3, 'invoice_dtm': '12/01/2013'}
# {'invoice_id': '92186', 'quantity': 4, 'invoice_dtm': '10/09/2014'}
# {'invoice_id': '242144', 'quantity': 4, 'invoice_dtm': '09/11/2018'}
# {'invoice_id': '131404', 'quantity': 6, 'invoice_dtm': '21/02/2011'}
# {'invoice_id': '196967', 'quantity': 3, 'invoice_dtm': '17/06/2021'}
# {'invoice_id': '212771', 'quantity': 3, 'invoice_dtm': '10/09/2013'}
# {'invoice_id': '8082', 'quantity': 3, 'invoice_dtm': '15/05/2016'}
# {'invoice_id': '31823', 'quantity': 3, 'invoice_dtm': '19/04/2016'}
# {'invoice_id': '454135', 'quantity': 24, 'invoice_dtm': '19/08/2018'}
# {'invoice_id': '303983', 'quantity': 24, 'invoice_dtm': '22/07/2022'}
# {'invoice_id': '305983', 'quantity': 12, 'invoice_dtm': '21/09/2014'}
# {'invoice_id': '378851', 'quantity': 12, 'invoice_dtm': '28/05/2012'}
# {'invoice_id': '336254', 'quantity': 24, 'invoice_dtm': '12/01/2013'}
# {'invoice_id': '279259', 'quantity': 48, 'invoice_dtm': '14/05/2014'}
# {'invoice_id': '302729', 'quantity': 24, 'invoice_dtm': '16/01/2021'}
# {'invoice_id': '108116', 'quantity': 18, 'invoice_dtm': '11/07/2016'}
# {'invoice_id': '271510', 'quantity': 24, 'invoice_dtm': '10/12/2014'}
# {'invoice_id': '374553', 'quantity': 24, 'invoice_dtm': '07/06/2014'}
# {'invoice_id': '358581', 'quantity': 24, 'invoice_dtm': '08/07/2019'}
# {'invoice_id': '382934', 'quantity': 24, 'invoice_dtm': '26/03/2012'}
# {'invoice_id': '319640', 'quantity': 20, 'invoice_dtm': '23/09/2022'}
# {'invoice_id': '334321', 'quantity': 24, 'invoice_dtm': '15/03/2021'}
# {'invoice_id': '90358', 'quantity': 24, 'invoice_dtm': '31/01/2021'}
# {'invoice_id': '211442', 'quantity': 12, 'invoice_dtm': '17/11/2021'}
# {'invoice_id': '344931', 'quantity': 24, 'invoice_dtm': '13/06/2013'}
# {'invoice_id': '312122', 'quantity': 24, 'invoice_dtm': '24/05/2019'}
# {'invoice_id': '303238', 'quantity': 36, 'invoice_dtm': '23/11/2016'}
# {'invoice_id': '104737', 'quantity': 3, 'invoice_dtm': '11/07/2017'}
# {'invoice_id': '227878', 'quantity': 80, 'invoice_dtm': '02/03/2019'}
# {'invoice_id': '240361', 'quantity': 6, 'invoice_dtm': '13/04/2021'}
# {'invoice_id': '214615', 'quantity': 6, 'invoice_dtm': '03/02/2013'}
# {'invoice_id': '105008', 'quantity': 6, 'invoice_dtm': '31/08/2018'}
# {'invoice_id': '163759', 'quantity': 6, 'invoice_dtm': '20/07/2010'}
# {'invoice_id': '322893', 'quantity': 8, 'invoice_dtm': '19/07/2020'}
# {'invoice_id': '327592', 'quantity': 6, 'invoice_dtm': '21/03/2010'}
# {'invoice_id': '328438', 'quantity': 6, 'invoice_dtm': '20/10/2021'}
# {'invoice_id': '29539', 'quantity': 6, 'invoice_dtm': '03/08/2022'}
# {'invoice_id': '455846', 'quantity': 6, 'invoice_dtm': '20/03/2013'}
# {'invoice_id': '251833', 'quantity': 6, 'invoice_dtm': '11/09/2022'}
# {'invoice_id': '366781', 'quantity': 2, 'invoice_dtm': '26/10/2016'}
# {'invoice_id': '463278', 'quantity': 4, 'invoice_dtm': '29/04/2017'}
# {'invoice_id': '35646', 'quantity': 6, 'invoice_dtm': '01/01/2015'}
# {'invoice_id': '398983', 'quantity': 6, 'invoice_dtm': '30/05/2011'}
# {'invoice_id': '498296', 'quantity': 6, 'invoice_dtm': '30/05/2019'}
# {'invoice_id': '71330', 'quantity': 6, 'invoice_dtm': '26/02/2022'}
# {'invoice_id': '100213', 'quantity': 2, 'invoice_dtm': '03/12/2018'}
# {'invoice_id': '120376', 'quantity': 6, 'invoice_dtm': '15/07/2011'}
# {'invoice_id': '396886', 'quantity': 32, 'invoice_dtm': '23/06/2019'}
# {'invoice_id': '150073', 'quantity': 6, 'invoice_dtm': '22/05/2017'}
# {'invoice_id': '242827', 'quantity': 6, 'invoice_dtm': '22/07/2013'}
# {'invoice_id': '362120', 'quantity': 8, 'invoice_dtm': '12/09/2020'}
# {'invoice_id': '110553', 'quantity': 6, 'invoice_dtm': '06/04/2022'}
# {'invoice_id': '20239', 'quantity': 6, 'invoice_dtm': '23/10/2013'}
# {'invoice_id': '5214', 'quantity': 6, 'invoice_dtm': '29/03/2011'}
# {'invoice_id': '175185', 'quantity': 6, 'invoice_dtm': '26/06/2017'}
# {'invoice_id': '359766', 'quantity': 6, 'invoice_dtm': '26/03/2020'}
# {'invoice_id': '125463', 'quantity': 2, 'invoice_dtm': '26/02/2022'}
# {'invoice_id': '40146', 'quantity': 4, 'invoice_dtm': '10/02/2016'}
# {'invoice_id': '62362', 'quantity': 6, 'invoice_dtm': '18/08/2017'}
# {'invoice_id': '171511', 'quantity': 6, 'invoice_dtm': '12/11/2021'}
# {'invoice_id': '107611', 'quantity': 6, 'invoice_dtm': '04/04/2013'}
# {'invoice_id': '245414', 'quantity': 6, 'invoice_dtm': '02/09/2011'}
# {'invoice_id': '184702', 'quantity': 2, 'invoice_dtm': '23/10/2022'}
# {'invoice_id': '288479', 'quantity': 6, 'invoice_dtm': '29/10/2020'}
# {'invoice_id': '388989', 'quantity': 48, 'invoice_dtm': '14/08/2014'}
# {'invoice_id': '143766', 'quantity': 64, 'invoice_dtm': '11/05/2022'}
# {'invoice_id': '319014', 'quantity': 6, 'invoice_dtm': '08/03/2014'}
# {'invoice_id': '334000', 'quantity': 6, 'invoice_dtm': '29/01/2011'}
# {'invoice_id': '373830', 'quantity': 10, 'invoice_dtm': '28/04/2022'}
# {'invoice_id': '67912', 'quantity': 10, 'invoice_dtm': '12/10/2014'}
# {'invoice_id': '471729', 'quantity': 10, 'invoice_dtm': '22/12/2016'}
# {'invoice_id': '151443', 'quantity': 10, 'invoice_dtm': '18/05/2017'}
# {'invoice_id': '480869', 'quantity': 12, 'invoice_dtm': '31/07/2015'}
# {'invoice_id': '283571', 'quantity': 6, 'invoice_dtm': '14/04/2021'}
# {'invoice_id': '163228', 'quantity': 12, 'invoice_dtm': '27/10/2010'}
# {'invoice_id': '257493', 'quantity': 10, 'invoice_dtm': '07/06/2013'}
# {'invoice_id': '17052', 'quantity': 6, 'invoice_dtm': '31/08/2021'}
# {'invoice_id': '347999', 'quantity': 6, 'invoice_dtm': '01/07/2012'}
# {'invoice_id': '117202', 'quantity': 120, 'invoice_dtm': '14/01/2011'}
# {'invoice_id': '465681', 'quantity': 24, 'invoice_dtm': '27/10/2020'}
# {'invoice_id': '50308', 'quantity': 24, 'invoice_dtm': '19/08/2019'}
# {'invoice_id': '38540', 'quantity': 24, 'invoice_dtm': '05/06/2018'}
# {'invoice_id': '21907', 'quantity': 6, 'invoice_dtm': '25/07/2018'}
# {'invoice_id': '380977', 'quantity': 48, 'invoice_dtm': '15/11/2021'}
# {'invoice_id': '215414', 'quantity': 96, 'invoice_dtm': '24/06/2016'}
# {'invoice_id': '451604', 'quantity': 10, 'invoice_dtm': '31/01/2011'}
# {'invoice_id': '35460', 'quantity': 10, 'invoice_dtm': '08/02/2017'}
# {'invoice_id': '198027', 'quantity': 24, 'invoice_dtm': '12/09/2019'}
# {'invoice_id': '90898', 'quantity': 23, 'invoice_dtm': '14/10/2013'}
# {'invoice_id': '297671', 'quantity': 5, 'invoice_dtm': '15/05/2015'}
# {'invoice_id': '250638', 'quantity': 10, 'invoice_dtm': '20/11/2016'}
# {'invoice_id': '74747', 'quantity': 2, 'invoice_dtm': '18/01/2020'}
# {'invoice_id': '125386', 'quantity': 6, 'invoice_dtm': '10/10/2018'}
# {'invoice_id': '72519', 'quantity': 24, 'invoice_dtm': '08/01/2011'}
# {'invoice_id': '310913', 'quantity': 24, 'invoice_dtm': '21/10/2013'}
# {'invoice_id': '87688', 'quantity': 1, 'invoice_dtm': '15/06/2018'}
# {'invoice_id': '10996', 'quantity': 1, 'invoice_dtm': '04/04/2014'}
# {'invoice_id': '338244', 'quantity': 1, 'invoice_dtm': '17/08/2015'}
# {'invoice_id': '211354', 'quantity': 10, 'invoice_dtm': '20/04/2012'}
# {'invoice_id': '262052', 'quantity': 3, 'invoice_dtm': '13/07/2013'}
# {'invoice_id': '381352', 'quantity': 1, 'invoice_dtm': '11/05/2010'}
# {'invoice_id': '411056', 'quantity': 2, 'invoice_dtm': '01/08/2020'}
# {'invoice_id': '440635', 'quantity': 1, 'invoice_dtm': '18/11/2021'}
# {'invoice_id': '132737', 'quantity': 1, 'invoice_dtm': '23/03/2019'}
# {'invoice_id': '30941', 'quantity': 4, 'invoice_dtm': '16/03/2017'}
# {'invoice_id': '168932', 'quantity': 1, 'invoice_dtm': '18/02/2014'}
# {'invoice_id': '156004', 'quantity': 6, 'invoice_dtm': '12/07/2018'}
# {'invoice_id': '295342', 'quantity': 3, 'invoice_dtm': '01/01/2010'}
# {'invoice_id': '276248', 'quantity': 2, 'invoice_dtm': '15/01/2013'}
# {'invoice_id': '183788', 'quantity': 1, 'invoice_dtm': '22/11/2022'}
# {'invoice_id': '418968', 'quantity': 1, 'invoice_dtm': '17/10/2019'}
# {'invoice_id': '162486', 'quantity': 1, 'invoice_dtm': '18/10/2015'}
# {'invoice_id': '276959', 'quantity': 1, 'invoice_dtm': '17/06/2020'}
# {'invoice_id': '433180', 'quantity': 2, 'invoice_dtm': '02/07/2015'}
# {'invoice_id': '285586', 'quantity': 2, 'invoice_dtm': '23/09/2013'}
# {'invoice_id': '346683', 'quantity': 2, 'invoice_dtm': '07/08/2011'}
# {'invoice_id': '71392', 'quantity': 4, 'invoice_dtm': '22/04/2010'}
# {'invoice_id': '70576', 'quantity': 1, 'invoice_dtm': '13/05/2014'}
# {'invoice_id': '165795', 'quantity': 1, 'invoice_dtm': '20/06/2012'}
# {'invoice_id': '486827', 'quantity': 2, 'invoice_dtm': '05/04/2022'}
# {'invoice_id': '183332', 'quantity': 3, 'invoice_dtm': '22/02/2014'}
# {'invoice_id': '450135', 'quantity': 36, 'invoice_dtm': '04/11/2017'}
# {'invoice_id': '416896', 'quantity': 10, 'invoice_dtm': '08/03/2017'}
# {'invoice_id': '112971', 'quantity': -1, 'invoice_dtm': '13/05/2015'}
# {'invoice_id': '113456', 'quantity': 12, 'invoice_dtm': '21/02/2016'}
# {'invoice_id': '232625', 'quantity': 8, 'invoice_dtm': '12/01/2022'}
# {'invoice_id': '362265', 'quantity': 12, 'invoice_dtm': '06/03/2016'}
# {'invoice_id': '433243', 'quantity': 10, 'invoice_dtm': '11/03/2018'}
# {'invoice_id': '418455', 'quantity': 10, 'invoice_dtm': '28/06/2018'}
# {'invoice_id': '490750', 'quantity': 50, 'invoice_dtm': '26/04/2019'}
# {'invoice_id': '438323', 'quantity': 8, 'invoice_dtm': '22/02/2022'}
# {'invoice_id': '12849', 'quantity': 4, 'invoice_dtm': '29/05/2019'}
# {'invoice_id': '201180', 'quantity': 12, 'invoice_dtm': '11/03/2021'}
# {'invoice_id': '483606', 'quantity': 2, 'invoice_dtm': '28/10/2020'}
# {'invoice_id': '453896', 'quantity': 2, 'invoice_dtm': '11/02/2018'}
# {'invoice_id': '113900', 'quantity': 4, 'invoice_dtm': '05/09/2019'}
# {'invoice_id': '126908', 'quantity': -1, 'invoice_dtm': '18/06/2013'}
# {'invoice_id': '413485', 'quantity': 3, 'invoice_dtm': '02/03/2022'}
# {'invoice_id': '446532', 'quantity': 48, 'invoice_dtm': '07/02/2013'}
# {'invoice_id': '154704', 'quantity': 12, 'invoice_dtm': '30/10/2012'}
# {'invoice_id': '125808', 'quantity': 6, 'invoice_dtm': '02/09/2019'}
# {'invoice_id': '366002', 'quantity': 12, 'invoice_dtm': '28/03/2020'}
# {'invoice_id': '57382', 'quantity': 40, 'invoice_dtm': '25/04/2022'}
# {'invoice_id': '251521', 'quantity': 40, 'invoice_dtm': '22/08/2016'}
# {'invoice_id': '381041', 'quantity': 6, 'invoice_dtm': '11/11/2016'}
# {'invoice_id': '330606', 'quantity': 2, 'invoice_dtm': '23/04/2020'}
# {'invoice_id': '497424', 'quantity': 4, 'invoice_dtm': '28/01/2020'}
# {'invoice_id': '242825', 'quantity': 3, 'invoice_dtm': '18/04/2021'}
# {'invoice_id': '341061', 'quantity': 6, 'invoice_dtm': '10/02/2010'}
# {'invoice_id': '183911', 'quantity': 8, 'invoice_dtm': '06/06/2016'}
# {'invoice_id': '12770', 'quantity': 1, 'invoice_dtm': '22/12/2013'}
# {'invoice_id': '176360', 'quantity': 12, 'invoice_dtm': '06/04/2022'}
# {'invoice_id': '328078', 'quantity': 6, 'invoice_dtm': '11/03/2016'}
# {'invoice_id': '293591', 'quantity': 10, 'invoice_dtm': '22/08/2011'}
# {'invoice_id': '392349', 'quantity': 12, 'invoice_dtm': '04/10/2018'}
# {'invoice_id': '470593', 'quantity': 2, 'invoice_dtm': '13/11/2016'}
# {'invoice_id': '414273', 'quantity': 10, 'invoice_dtm': '10/12/2022'}
# {'invoice_id': '213309', 'quantity': 36, 'invoice_dtm': '09/06/2011'}
# {'invoice_id': '293957', 'quantity': 100, 'invoice_dtm': '28/11/2019'}
# {'invoice_id': '246865', 'quantity': 100, 'invoice_dtm': '28/12/2010'}
# {'invoice_id': '379597', 'quantity': 192, 'invoice_dtm': '30/01/2011'}
# {'invoice_id': '417828', 'quantity': 192, 'invoice_dtm': '25/06/2018'}
# {'invoice_id': '424927', 'quantity': 192, 'invoice_dtm': '03/07/2021'}
# {'invoice_id': '192340', 'quantity': 432, 'invoice_dtm': '25/02/2019'}
# {'invoice_id': '5442', 'quantity': 432, 'invoice_dtm': '20/03/2018'}
# {'invoice_id': '247353', 'quantity': 3, 'invoice_dtm': '04/10/2018'}
# {'invoice_id': '168924', 'quantity': 3, 'invoice_dtm': '20/05/2016'}
# {'invoice_id': '186808', 'quantity': 2, 'invoice_dtm': '27/08/2011'}
# {'invoice_id': '241859', 'quantity': 3, 'invoice_dtm': '26/01/2019'}
# {'invoice_id': '387512', 'quantity': 3, 'invoice_dtm': '11/04/2010'}
# {'invoice_id': '376500', 'quantity': 6, 'invoice_dtm': '04/06/2013'}
# {'invoice_id': '6029', 'quantity': 12, 'invoice_dtm': '01/03/2017'}
# {'invoice_id': '438071', 'quantity': 12, 'invoice_dtm': '18/09/2013'}
# {'invoice_id': '261634', 'quantity': 12, 'invoice_dtm': '04/01/2017'}
# {'invoice_id': '210032', 'quantity': 12, 'invoice_dtm': '30/07/2014'}
# {'invoice_id': '130305', 'quantity': 12, 'invoice_dtm': '07/06/2022'}
# {'invoice_id': '432116', 'quantity': 4, 'invoice_dtm': '27/06/2019'}
# {'invoice_id': '234670', 'quantity': 12, 'invoice_dtm': '08/06/2017'}
# {'invoice_id': '221168', 'quantity': 12, 'invoice_dtm': '06/03/2020'}
# {'invoice_id': '139124', 'quantity': 6, 'invoice_dtm': '29/05/2010'}
# {'invoice_id': '420950', 'quantity': 8, 'invoice_dtm': '14/03/2015'}
# {'invoice_id': '15941', 'quantity': 12, 'invoice_dtm': '04/08/2018'}
# {'invoice_id': '146912', 'quantity': 6, 'invoice_dtm': '04/03/2012'}
# {'invoice_id': '374943', 'quantity': 4, 'invoice_dtm': '06/01/2016'}
# {'invoice_id': '154241', 'quantity': 6, 'invoice_dtm': '07/12/2019'}
# {'invoice_id': '9224', 'quantity': 3, 'invoice_dtm': '11/11/2016'}
# {'invoice_id': '116706', 'quantity': 2, 'invoice_dtm': '13/11/2017'}
# {'invoice_id': '16114', 'quantity': 4, 'invoice_dtm': '21/10/2015'}
# {'invoice_id': '426856', 'quantity': 4, 'invoice_dtm': '25/08/2022'}
# {'invoice_id': '162197', 'quantity': 2, 'invoice_dtm': '20/11/2011'}
# {'invoice_id': '368078', 'quantity': 2, 'invoice_dtm': '10/09/2010'}
# {'invoice_id': '252242', 'quantity': 24, 'invoice_dtm': '09/11/2015'}
# {'invoice_id': '335945', 'quantity': 24, 'invoice_dtm': '09/12/2015'}
# {'invoice_id': '491227', 'quantity': 2, 'invoice_dtm': '02/10/2018'}
# {'invoice_id': '324578', 'quantity': 12, 'invoice_dtm': '14/02/2013'}
# {'invoice_id': '476539', 'quantity': 12, 'invoice_dtm': '15/06/2017'}
# {'invoice_id': '399521', 'quantity': 48, 'invoice_dtm': '21/02/2016'}
# {'invoice_id': '161373', 'quantity': 48, 'invoice_dtm': '30/07/2018'}
# {'invoice_id': '91790', 'quantity': 8, 'invoice_dtm': '17/06/2020'}
# {'invoice_id': '153689', 'quantity': 144, 'invoice_dtm': '19/06/2021'}
# {'invoice_id': '8150', 'quantity': 40, 'invoice_dtm': '24/09/2016'}
# {'invoice_id': '244570', 'quantity': 288, 'invoice_dtm': '08/11/2022'}
# {'invoice_id': '206983', 'quantity': 64, 'invoice_dtm': '12/11/2010'}
# {'invoice_id': '96032', 'quantity': 100, 'invoice_dtm': '08/07/2013'}
# {'invoice_id': '167410', 'quantity': 50, 'invoice_dtm': '23/10/2017'}
# {'invoice_id': '122315', 'quantity': 12, 'invoice_dtm': '03/01/2014'}
# {'invoice_id': '441132', 'quantity': 96, 'invoice_dtm': '02/09/2013'}
# {'invoice_id': '55796', 'quantity': 96, 'invoice_dtm': '01/05/2010'}
# {'invoice_id': '147513', 'quantity': 48, 'invoice_dtm': '28/12/2010'}
# {'invoice_id': '390197', 'quantity': 144, 'invoice_dtm': '20/03/2016'}
# {'invoice_id': '202712', 'quantity': 40, 'invoice_dtm': '27/01/2015'}
# {'invoice_id': '237902', 'quantity': 24, 'invoice_dtm': '14/12/2020'}
# {'invoice_id': '495486', 'quantity': 24, 'invoice_dtm': '12/11/2022'}
# {'invoice_id': '169784', 'quantity': 24, 'invoice_dtm': '21/11/2012'}
# {'invoice_id': '305001', 'quantity': 48, 'invoice_dtm': '18/10/2017'}
# {'invoice_id': '426094', 'quantity': 96, 'invoice_dtm': '05/03/2014'}
# {'invoice_id': '157487', 'quantity': 100, 'invoice_dtm': '10/06/2016'}
# {'invoice_id': '143622', 'quantity': -12, 'invoice_dtm': '19/08/2013'}
# {'invoice_id': '378182', 'quantity': -24, 'invoice_dtm': '01/01/2014'}
# {'invoice_id': '164634', 'quantity': -24, 'invoice_dtm': '28/08/2018'}
# {'invoice_id': '57609', 'quantity': -24, 'invoice_dtm': '30/10/2017'}
# {'invoice_id': '466641', 'quantity': -12, 'invoice_dtm': '25/07/2022'}
# {'invoice_id': '113495', 'quantity': -12, 'invoice_dtm': '30/06/2013'}
# {'invoice_id': '144544', 'quantity': -24, 'invoice_dtm': '03/01/2012'}
# {'invoice_id': '190554', 'quantity': 6, 'invoice_dtm': '28/05/2011'}
# {'invoice_id': '300142', 'quantity': 4, 'invoice_dtm': '29/09/2011'}
# {'invoice_id': '438661', 'quantity': 12, 'invoice_dtm': '27/10/2015'}
# {'invoice_id': '415467', 'quantity': 12, 'invoice_dtm': '22/07/2019'}
# {'invoice_id': '123881', 'quantity': 1, 'invoice_dtm': '03/09/2019'}
# {'invoice_id': '71670', 'quantity': 12, 'invoice_dtm': '30/11/2011'}
# {'invoice_id': '183418', 'quantity': 12, 'invoice_dtm': '24/11/2021'}
# {'invoice_id': '35129', 'quantity': 4, 'invoice_dtm': '15/02/2010'}
# {'invoice_id': '397511', 'quantity': 16, 'invoice_dtm': '20/05/2016'}
# {'invoice_id': '17597', 'quantity': 24, 'invoice_dtm': '09/03/2017'}
# {'invoice_id': '117773', 'quantity': 8, 'invoice_dtm': '02/07/2016'}
# {'invoice_id': '77204', 'quantity': 24, 'invoice_dtm': '08/11/2012'}
# {'invoice_id': '99031', 'quantity': 96, 'invoice_dtm': '14/02/2014'}
# {'invoice_id': '363663', 'quantity': 96, 'invoice_dtm': '01/11/2020'}
# {'invoice_id': '488862', 'quantity': 96, 'invoice_dtm': '15/08/2017'}
# {'invoice_id': '76094', 'quantity': 96, 'invoice_dtm': '29/07/2020'}
# {'invoice_id': '354980', 'quantity': 12, 'invoice_dtm': '19/01/2016'}
# {'invoice_id': '222357', 'quantity': 12, 'invoice_dtm': '20/08/2022'}
# {'invoice_id': '120787', 'quantity': 48, 'invoice_dtm': '07/03/2014'}
# {'invoice_id': '33664', 'quantity': 12, 'invoice_dtm': '18/06/2010'}
# {'invoice_id': '305051', 'quantity': 32, 'invoice_dtm': '26/11/2018'}
# {'invoice_id': '40486', 'quantity': 20, 'invoice_dtm': '07/05/2014'}
# {'invoice_id': '170153', 'quantity': 8, 'invoice_dtm': '11/09/2020'}
# {'invoice_id': '379796', 'quantity': 32, 'invoice_dtm': '19/02/2010'}
# {'invoice_id': '77476', 'quantity': 24, 'invoice_dtm': '08/04/2019'}
# {'invoice_id': '151064', 'quantity': 24, 'invoice_dtm': '29/10/2011'}
# {'invoice_id': '304723', 'quantity': 24, 'invoice_dtm': '26/12/2011'}
# {'invoice_id': '309018', 'quantity': 8, 'invoice_dtm': '06/09/2015'}
# {'invoice_id': '212943', 'quantity': 8, 'invoice_dtm': '03/06/2012'}
# {'invoice_id': '374709', 'quantity': 4, 'invoice_dtm': '20/09/2019'}
# {'invoice_id': '478500', 'quantity': 8, 'invoice_dtm': '29/12/2018'}
# {'invoice_id': '485670', 'quantity': 8, 'invoice_dtm': '25/12/2019'}
# {'invoice_id': '61194', 'quantity': 8, 'invoice_dtm': '27/01/2020'}
# {'invoice_id': '339349', 'quantity': 8, 'invoice_dtm': '28/03/2012'}
# {'invoice_id': '364627', 'quantity': 48, 'invoice_dtm': '11/12/2018'}
# {'invoice_id': '31541', 'quantity': 48, 'invoice_dtm': '05/06/2012'}
# {'invoice_id': '456122', 'quantity': 6, 'invoice_dtm': '22/07/2012'}
# {'invoice_id': '50765', 'quantity': 6, 'invoice_dtm': '11/06/2017'}
# {'invoice_id': '345883', 'quantity': 8, 'invoice_dtm': '20/01/2013'}
# {'invoice_id': '411805', 'quantity': 6, 'invoice_dtm': '14/11/2013'}
# {'invoice_id': '169009', 'quantity': 6, 'invoice_dtm': '27/07/2015'}
# {'invoice_id': '365420', 'quantity': 6, 'invoice_dtm': '10/11/2013'}
# {'invoice_id': '375297', 'quantity': 6, 'invoice_dtm': '24/09/2011'}
# {'invoice_id': '189757', 'quantity': 6, 'invoice_dtm': '24/08/2022'}
# {'invoice_id': '257525', 'quantity': 6, 'invoice_dtm': '30/10/2017'}
# {'invoice_id': '429264', 'quantity': 2, 'invoice_dtm': '29/10/2015'}
# {'invoice_id': '308398', 'quantity': 4, 'invoice_dtm': '15/06/2022'}
# {'invoice_id': '131662', 'quantity': 6, 'invoice_dtm': '02/05/2018'}
# {'invoice_id': '27889', 'quantity': 12, 'invoice_dtm': '07/10/2021'}
# {'invoice_id': '107641', 'quantity': 6, 'invoice_dtm': '12/09/2011'}
# {'invoice_id': '405413', 'quantity': 6, 'invoice_dtm': '29/12/2021'}
# {'invoice_id': '275858', 'quantity': 2, 'invoice_dtm': '24/11/2019'}
# {'invoice_id': '150162', 'quantity': 2, 'invoice_dtm': '23/04/2011'}
# {'invoice_id': '458960', 'quantity': 6, 'invoice_dtm': '03/12/2022'}
# {'invoice_id': '280960', 'quantity': 12, 'invoice_dtm': '21/03/2022'}
# {'invoice_id': '127362', 'quantity': 48, 'invoice_dtm': '16/12/2011'}
# {'invoice_id': '44436', 'quantity': 24, 'invoice_dtm': '19/02/2020'}
# {'invoice_id': '342881', 'quantity': 6, 'invoice_dtm': '31/07/2019'}
# {'invoice_id': '358252', 'quantity': 4, 'invoice_dtm': '03/04/2019'}
# {'invoice_id': '71685', 'quantity': 8, 'invoice_dtm': '27/09/2018'}
# {'invoice_id': '345243', 'quantity': 6, 'invoice_dtm': '12/04/2020'}
# {'invoice_id': '16116', 'quantity': 2, 'invoice_dtm': '22/09/2012'}
# {'invoice_id': '420676', 'quantity': 12, 'invoice_dtm': '13/03/2015'}
# {'invoice_id': '171918', 'quantity': 12, 'invoice_dtm': '19/02/2018'}
# {'invoice_id': '291796', 'quantity': 12, 'invoice_dtm': '09/08/2017'}
# {'invoice_id': '492937', 'quantity': 12, 'invoice_dtm': '20/12/2013'}
# {'invoice_id': '341182', 'quantity': 12, 'invoice_dtm': '06/05/2017'}
# {'invoice_id': '259891', 'quantity': 6, 'invoice_dtm': '19/04/2020'}
# {'invoice_id': '282864', 'quantity': 4, 'invoice_dtm': '09/10/2011'}
# {'invoice_id': '456310', 'quantity': 8, 'invoice_dtm': '21/11/2018'}
# {'invoice_id': '146789', 'quantity': 9, 'invoice_dtm': '26/10/2013'}
# {'invoice_id': '417649', 'quantity': 4, 'invoice_dtm': '23/11/2015'}
# {'invoice_id': '488650', 'quantity': 9, 'invoice_dtm': '11/12/2012'}
# {'invoice_id': '19851', 'quantity': 6, 'invoice_dtm': '07/04/2018'}
# {'invoice_id': '172489', 'quantity': 6, 'invoice_dtm': '06/06/2013'}
# {'invoice_id': '129387', 'quantity': 12, 'invoice_dtm': '23/02/2012'}
# {'invoice_id': '9087', 'quantity': 1, 'invoice_dtm': '27/10/2016'}
# {'invoice_id': '498029', 'quantity': 1, 'invoice_dtm': '27/03/2012'}
# {'invoice_id': '289567', 'quantity': 2, 'invoice_dtm': '24/07/2020'}
# {'invoice_id': '358478', 'quantity': 1, 'invoice_dtm': '08/10/2014'}
# {'invoice_id': '280796', 'quantity': 1, 'invoice_dtm': '07/07/2019'}
# {'invoice_id': '65952', 'quantity': 1, 'invoice_dtm': '01/10/2012'}
# {'invoice_id': '391310', 'quantity': 1, 'invoice_dtm': '21/10/2016'}
# {'invoice_id': '327262', 'quantity': 2, 'invoice_dtm': '19/11/2020'}
# {'invoice_id': '418058', 'quantity': 1, 'invoice_dtm': '28/08/2012'}
# {'invoice_id': '290929', 'quantity': 4, 'invoice_dtm': '29/06/2014'}
# {'invoice_id': '396545', 'quantity': 1, 'invoice_dtm': '11/02/2012'}
# {'invoice_id': '169647', 'quantity': 1, 'invoice_dtm': '24/12/2015'}
# {'invoice_id': '275751', 'quantity': 2, 'invoice_dtm': '13/06/2015'}
# {'invoice_id': '408046', 'quantity': 2, 'invoice_dtm': '31/10/2019'}
# {'invoice_id': '369768', 'quantity': 2, 'invoice_dtm': '21/03/2014'}
# {'invoice_id': '384240', 'quantity': 1, 'invoice_dtm': '07/04/2019'}
# {'invoice_id': '235357', 'quantity': 1, 'invoice_dtm': '07/03/2021'}
# {'invoice_id': '474653', 'quantity': 1, 'invoice_dtm': '26/10/2022'}
# {'invoice_id': '249538', 'quantity': 3, 'invoice_dtm': '11/09/2022'}
# {'invoice_id': '304520', 'quantity': 1, 'invoice_dtm': '26/11/2012'}
# {'invoice_id': '74096', 'quantity': 1, 'invoice_dtm': '04/11/2018'}
# {'invoice_id': '181921', 'quantity': 2, 'invoice_dtm': '28/02/2020'}
# {'invoice_id': '445130', 'quantity': 1, 'invoice_dtm': '22/02/2019'}
# {'invoice_id': '447819', 'quantity': 1, 'invoice_dtm': '20/10/2018'}
# {'invoice_id': '489563', 'quantity': 1, 'invoice_dtm': '03/05/2018'}
# {'invoice_id': '406000', 'quantity': 2, 'invoice_dtm': '27/12/2017'}
# {'invoice_id': '148172', 'quantity': 4, 'invoice_dtm': '11/02/2019'}
# {'invoice_id': '233079', 'quantity': 2, 'invoice_dtm': '05/02/2014'}
# {'invoice_id': '140402', 'quantity': 1, 'invoice_dtm': '10/08/2021'}
# {'invoice_id': '303262', 'quantity': 1, 'invoice_dtm': '27/04/2019'}
# {'invoice_id': '275758', 'quantity': 1, 'invoice_dtm': '05/05/2013'}
# {'invoice_id': '122559', 'quantity': 3, 'invoice_dtm': '05/07/2012'}
# {'invoice_id': '469184', 'quantity': 1, 'invoice_dtm': '02/11/2017'}
# {'invoice_id': '317400', 'quantity': 1, 'invoice_dtm': '16/01/2022'}
# {'invoice_id': '439526', 'quantity': 2, 'invoice_dtm': '12/12/2011'}
# {'invoice_id': '205843', 'quantity': 3, 'invoice_dtm': '10/07/2012'}
# {'invoice_id': '65337', 'quantity': 1, 'invoice_dtm': '05/11/2019'}
# {'invoice_id': '423683', 'quantity': 1, 'invoice_dtm': '28/09/2010'}
# {'invoice_id': '325214', 'quantity': 2, 'invoice_dtm': '04/07/2012'}
# {'invoice_id': '430301', 'quantity': 2, 'invoice_dtm': '08/06/2021'}
# {'invoice_id': '285943', 'quantity': 2, 'invoice_dtm': '27/04/2014'}
# {'invoice_id': '387153', 'quantity': 1, 'invoice_dtm': '10/04/2011'}
# {'invoice_id': '41920', 'quantity': 1, 'invoice_dtm': '05/12/2010'}
# {'invoice_id': '169450', 'quantity': 2, 'invoice_dtm': '03/10/2012'}
# {'invoice_id': '205677', 'quantity': 9, 'invoice_dtm': '24/10/2012'}
# {'invoice_id': '112803', 'quantity': 1, 'invoice_dtm': '24/10/2010'}
# {'invoice_id': '81318', 'quantity': 4, 'invoice_dtm': '08/05/2019'}
# {'invoice_id': '462377', 'quantity': 3, 'invoice_dtm': '06/07/2010'}
# {'invoice_id': '203723', 'quantity': 1, 'invoice_dtm': '17/09/2012'}
# {'invoice_id': '346691', 'quantity': 1, 'invoice_dtm': '02/02/2021'}
# {'invoice_id': '109980', 'quantity': 1, 'invoice_dtm': '06/09/2022'}
# {'invoice_id': '1309', 'quantity': 2, 'invoice_dtm': '20/04/2015'}
# {'invoice_id': '481238', 'quantity': 1, 'invoice_dtm': '02/02/2012'}
# {'invoice_id': '300630', 'quantity': 1, 'invoice_dtm': '21/10/2018'}
# {'invoice_id': '186464', 'quantity': 5, 'invoice_dtm': '25/08/2011'}
# {'invoice_id': '336541', 'quantity': 3, 'invoice_dtm': '29/05/2019'}
# {'invoice_id': '499116', 'quantity': 3, 'invoice_dtm': '27/09/2020'}
# {'invoice_id': '162709', 'quantity': 9, 'invoice_dtm': '15/12/2021'}
# {'invoice_id': '135250', 'quantity': 1, 'invoice_dtm': '19/05/2013'}
# {'invoice_id': '393879', 'quantity': 4, 'invoice_dtm': '14/02/2012'}
# {'invoice_id': '229739', 'quantity': 1, 'invoice_dtm': '11/11/2015'}
# {'invoice_id': '31452', 'quantity': 1, 'invoice_dtm': '27/04/2010'}
# {'invoice_id': '18622', 'quantity': 2, 'invoice_dtm': '01/12/2010'}
# {'invoice_id': '166955', 'quantity': 2, 'invoice_dtm': '29/12/2014'}
# {'invoice_id': '439288', 'quantity': 40, 'invoice_dtm': '24/07/2012'}
# {'invoice_id': '404382', 'quantity': 40, 'invoice_dtm': '19/06/2012'}
# {'invoice_id': '129340', 'quantity': 36, 'invoice_dtm': '07/06/2015'}
# {'invoice_id': '180548', 'quantity': 96, 'invoice_dtm': '30/06/2022'}
# {'invoice_id': '427592', 'quantity': 1, 'invoice_dtm': '25/02/2019'}
# {'invoice_id': '121617', 'quantity': 24, 'invoice_dtm': '28/12/2020'}
# {'invoice_id': '146224', 'quantity': 12, 'invoice_dtm': '09/05/2020'}
# {'invoice_id': '109350', 'quantity': 12, 'invoice_dtm': '26/07/2010'}
# {'invoice_id': '307319', 'quantity': 12, 'invoice_dtm': '03/03/2018'}
# {'invoice_id': '486015', 'quantity': 12, 'invoice_dtm': '22/04/2022'}
# {'invoice_id': '289810', 'quantity': 12, 'invoice_dtm': '17/09/2020'}
# {'invoice_id': '416350', 'quantity': 36, 'invoice_dtm': '25/09/2015'}
# {'invoice_id': '256965', 'quantity': 12, 'invoice_dtm': '03/03/2017'}
# {'invoice_id': '124949', 'quantity': 12, 'invoice_dtm': '16/07/2010'}
# {'invoice_id': '325715', 'quantity': 12, 'invoice_dtm': '04/10/2016'}
# {'invoice_id': '285446', 'quantity': 12, 'invoice_dtm': '17/10/2017'}
# {'invoice_id': '10684', 'quantity': 12, 'invoice_dtm': '10/11/2020'}
# {'invoice_id': '398780', 'quantity': 12, 'invoice_dtm': '20/10/2012'}
# {'invoice_id': '151076', 'quantity': 12, 'invoice_dtm': '21/12/2014'}
# {'invoice_id': '266564', 'quantity': 12, 'invoice_dtm': '02/03/2015'}
# {'invoice_id': '398640', 'quantity': 12, 'invoice_dtm': '11/05/2022'}
# {'invoice_id': '28083', 'quantity': 12, 'invoice_dtm': '20/08/2019'}
# {'invoice_id': '98033', 'quantity': 12, 'invoice_dtm': '17/08/2019'}
# {'invoice_id': '366939', 'quantity': 12, 'invoice_dtm': '17/02/2014'}
# {'invoice_id': '37812', 'quantity': 24, 'invoice_dtm': '17/11/2022'}
# {'invoice_id': '258558', 'quantity': 24, 'invoice_dtm': '09/01/2011'}
# {'invoice_id': '399319', 'quantity': 24, 'invoice_dtm': '18/12/2013'}
# {'invoice_id': '246438', 'quantity': 24, 'invoice_dtm': '08/06/2018'}
# {'invoice_id': '210900', 'quantity': 24, 'invoice_dtm': '20/06/2015'}
# {'invoice_id': '396086', 'quantity': 10, 'invoice_dtm': '06/12/2017'}
# {'invoice_id': '179770', 'quantity': 10, 'invoice_dtm': '05/06/2018'}
# {'invoice_id': '132932', 'quantity': 10, 'invoice_dtm': '23/04/2022'}
# {'invoice_id': '264076', 'quantity': 24, 'invoice_dtm': '06/06/2012'}
# {'invoice_id': '225497', 'quantity': 128, 'invoice_dtm': '05/09/2014'}
# {'invoice_id': '360796', 'quantity': 8, 'invoice_dtm': '28/12/2015'}
# {'invoice_id': '39943', 'quantity': 8, 'invoice_dtm': '21/07/2015'}
# {'invoice_id': '414435', 'quantity': 8, 'invoice_dtm': '19/09/2011'}
# {'invoice_id': '9961', 'quantity': 6, 'invoice_dtm': '16/02/2017'}
# {'invoice_id': '365037', 'quantity': 6, 'invoice_dtm': '16/03/2015'}
# {'invoice_id': '93409', 'quantity': 6, 'invoice_dtm': '31/10/2013'}
# {'invoice_id': '278523', 'quantity': 6, 'invoice_dtm': '22/04/2014'}
# {'invoice_id': '238544', 'quantity': 6, 'invoice_dtm': '17/05/2020'}
# {'invoice_id': '170911', 'quantity': 4, 'invoice_dtm': '25/11/2014'}
# {'invoice_id': '492976', 'quantity': 4, 'invoice_dtm': '10/03/2014'}
# {'invoice_id': '247747', 'quantity': 6, 'invoice_dtm': '30/12/2013'}
# {'invoice_id': '210902', 'quantity': 6, 'invoice_dtm': '19/04/2016'}
# {'invoice_id': '33154', 'quantity': 6, 'invoice_dtm': '18/04/2010'}
# {'invoice_id': '282326', 'quantity': 6, 'invoice_dtm': '04/08/2013'}
# {'invoice_id': '204292', 'quantity': 2, 'invoice_dtm': '27/07/2010'}
# {'invoice_id': '336844', 'quantity': 2, 'invoice_dtm': '29/05/2014'}
# {'invoice_id': '303007', 'quantity': 6, 'invoice_dtm': '10/12/2015'}
# {'invoice_id': '154203', 'quantity': 6, 'invoice_dtm': '23/08/2015'}
# {'invoice_id': '424640', 'quantity': 6, 'invoice_dtm': '04/09/2012'}
# {'invoice_id': '252437', 'quantity': 24, 'invoice_dtm': '14/12/2015'}
# {'invoice_id': '275023', 'quantity': 24, 'invoice_dtm': '14/12/2020'}
# {'invoice_id': '133797', 'quantity': 12, 'invoice_dtm': '08/05/2022'}
# {'invoice_id': '49839', 'quantity': 12, 'invoice_dtm': '10/03/2015'}
# {'invoice_id': '180682', 'quantity': 12, 'invoice_dtm': '11/05/2020'}
# {'invoice_id': '435701', 'quantity': 12, 'invoice_dtm': '28/02/2011'}
# {'invoice_id': '298100', 'quantity': 12, 'invoice_dtm': '19/08/2018'}
# {'invoice_id': '176566', 'quantity': 12, 'invoice_dtm': '11/04/2013'}
# {'invoice_id': '356111', 'quantity': 4, 'invoice_dtm': '25/03/2011'}
# {'invoice_id': '150857', 'quantity': 4, 'invoice_dtm': '20/01/2012'}
# {'invoice_id': '387267', 'quantity': 4, 'invoice_dtm': '30/05/2020'}
# {'invoice_id': '264236', 'quantity': 6, 'invoice_dtm': '23/08/2015'}
# {'invoice_id': '481553', 'quantity': 12, 'invoice_dtm': '02/12/2014'}
# {'invoice_id': '244949', 'quantity': 24, 'invoice_dtm': '07/12/2017'}
# {'invoice_id': '348214', 'quantity': 12, 'invoice_dtm': '12/06/2021'}
# {'invoice_id': '142710', 'quantity': 12, 'invoice_dtm': '18/03/2019'}
# {'invoice_id': '535', 'quantity': 6, 'invoice_dtm': '06/11/2014'}
# {'invoice_id': '419858', 'quantity': 12, 'invoice_dtm': '08/06/2010'}
# {'invoice_id': '144955', 'quantity': 6, 'invoice_dtm': '19/04/2016'}
# {'invoice_id': '291243', 'quantity': 2, 'invoice_dtm': '01/11/2019'}
# {'invoice_id': '355450', 'quantity': 2, 'invoice_dtm': '06/12/2011'}
# {'invoice_id': '247340', 'quantity': 12, 'invoice_dtm': '26/12/2016'}
# {'invoice_id': '155632', 'quantity': 12, 'invoice_dtm': '08/06/2013'}
# {'invoice_id': '445701', 'quantity': 8, 'invoice_dtm': '10/10/2013'}
# {'invoice_id': '343803', 'quantity': 3, 'invoice_dtm': '05/10/2011'}
# {'invoice_id': '199068', 'quantity': 3, 'invoice_dtm': '30/03/2015'}
# {'invoice_id': '259040', 'quantity': 8, 'invoice_dtm': '05/08/2022'}
# {'invoice_id': '208849', 'quantity': 36, 'invoice_dtm': '17/06/2011'}
# {'invoice_id': '476268', 'quantity': 12, 'invoice_dtm': '01/01/2010'}
# {'invoice_id': '417181', 'quantity': 25, 'invoice_dtm': '01/08/2017'}
# {'invoice_id': '375218', 'quantity': 4, 'invoice_dtm': '16/05/2018'}
# {'invoice_id': '208137', 'quantity': 3, 'invoice_dtm': '16/01/2012'}
# {'invoice_id': '195336', 'quantity': 3, 'invoice_dtm': '30/06/2012'}
# {'invoice_id': '227328', 'quantity': 6, 'invoice_dtm': '23/11/2020'}
# {'invoice_id': '254639', 'quantity': 24, 'invoice_dtm': '24/04/2017'}
# {'invoice_id': '6099', 'quantity': 12, 'invoice_dtm': '20/07/2010'}
# {'invoice_id': '27795', 'quantity': 3, 'invoice_dtm': '20/05/2012'}
# {'invoice_id': '79569', 'quantity': 12, 'invoice_dtm': '12/09/2019'}
# {'invoice_id': '215394', 'quantity': 30, 'invoice_dtm': '17/09/2022'}
# {'invoice_id': '238634', 'quantity': 12, 'invoice_dtm': '30/03/2012'}
# {'invoice_id': '242405', 'quantity': 12, 'invoice_dtm': '31/10/2022'}
# {'invoice_id': '132798', 'quantity': 6, 'invoice_dtm': '09/10/2010'}
# {'invoice_id': '103552', 'quantity': 12, 'invoice_dtm': '27/04/2019'}
# {'invoice_id': '473012', 'quantity': 10, 'invoice_dtm': '12/04/2011'}
# {'invoice_id': '352764', 'quantity': 36, 'invoice_dtm': '19/06/2019'}
# {'invoice_id': '202432', 'quantity': 12, 'invoice_dtm': '06/11/2021'}
# {'invoice_id': '135571', 'quantity': 4, 'invoice_dtm': '22/07/2014'}
# {'invoice_id': '123710', 'quantity': 12, 'invoice_dtm': '30/04/2020'}
# {'invoice_id': '478065', 'quantity': 3, 'invoice_dtm': '24/12/2015'}
# {'invoice_id': '198784', 'quantity': 1, 'invoice_dtm': '14/03/2014'}
# {'invoice_id': '187502', 'quantity': 1, 'invoice_dtm': '06/09/2014'}
# {'invoice_id': '494546', 'quantity': 1, 'invoice_dtm': '30/09/2016'}
# {'invoice_id': '264078', 'quantity': 1, 'invoice_dtm': '26/03/2012'}
# {'invoice_id': '395', 'quantity': 1, 'invoice_dtm': '29/12/2017'}
# {'invoice_id': '161618', 'quantity': 1, 'invoice_dtm': '21/08/2011'}
# {'invoice_id': '115270', 'quantity': 1, 'invoice_dtm': '14/10/2011'}
# {'invoice_id': '199696', 'quantity': 1, 'invoice_dtm': '27/06/2022'}
# {'invoice_id': '399348', 'quantity': 1, 'invoice_dtm': '19/09/2016'}
# {'invoice_id': '441185', 'quantity': 1, 'invoice_dtm': '24/08/2014'}
# {'invoice_id': '385684', 'quantity': 1, 'invoice_dtm': '15/02/2011'}
# {'invoice_id': '174587', 'quantity': 1, 'invoice_dtm': '12/08/2010'}
# {'invoice_id': '419129', 'quantity': 1, 'invoice_dtm': '22/10/2015'}
# {'invoice_id': '499026', 'quantity': 1, 'invoice_dtm': '06/10/2020'}
# {'invoice_id': '187406', 'quantity': 1, 'invoice_dtm': '29/10/2020'}
# {'invoice_id': '291950', 'quantity': 1, 'invoice_dtm': '25/02/2010'}
# {'invoice_id': '425977', 'quantity': 1, 'invoice_dtm': '08/02/2015'}
# {'invoice_id': '123806', 'quantity': 1, 'invoice_dtm': '20/09/2018'}
# {'invoice_id': '35462', 'quantity': 5, 'invoice_dtm': '20/05/2017'}
# {'invoice_id': '267769', 'quantity': 1, 'invoice_dtm': '26/11/2014'}
# {'invoice_id': '11923', 'quantity': 1, 'invoice_dtm': '06/07/2017'}
# {'invoice_id': '418799', 'quantity': 1, 'invoice_dtm': '21/12/2017'}
# {'invoice_id': '310119', 'quantity': 6, 'invoice_dtm': '24/02/2011'}
# {'invoice_id': '143498', 'quantity': 6, 'invoice_dtm': '23/04/2014'}
# {'invoice_id': '467078', 'quantity': 1, 'invoice_dtm': '17/12/2010'}
# {'invoice_id': '440536', 'quantity': 3, 'invoice_dtm': '21/10/2012'}
# {'invoice_id': '201788', 'quantity': 2, 'invoice_dtm': '22/12/2021'}
# {'invoice_id': '179548', 'quantity': 12, 'invoice_dtm': '21/12/2015'}
# {'invoice_id': '238756', 'quantity': 28, 'invoice_dtm': '24/02/2017'}
# {'invoice_id': '293179', 'quantity': 24, 'invoice_dtm': '19/08/2017'}
# {'invoice_id': '339565', 'quantity': 1, 'invoice_dtm': '02/01/2011'}
# {'invoice_id': '185065', 'quantity': 1, 'invoice_dtm': '26/10/2015'}
# {'invoice_id': '249071', 'quantity': 1, 'invoice_dtm': '03/06/2014'}
# {'invoice_id': '431029', 'quantity': 1, 'invoice_dtm': '12/10/2016'}
# {'invoice_id': '75475', 'quantity': 12, 'invoice_dtm': '14/12/2016'}
# {'invoice_id': '496639', 'quantity': 1, 'invoice_dtm': '19/01/2019'}
# {'invoice_id': '20435', 'quantity': 1, 'invoice_dtm': '26/12/2010'}
# {'invoice_id': '191132', 'quantity': 1, 'invoice_dtm': '24/12/2015'}
# {'invoice_id': '474900', 'quantity': 1, 'invoice_dtm': '23/05/2018'}
# {'invoice_id': '78169', 'quantity': 2, 'invoice_dtm': '03/01/2016'}
# {'invoice_id': '475551', 'quantity': 1, 'invoice_dtm': '30/06/2012'}
# {'invoice_id': '486406', 'quantity': 2, 'invoice_dtm': '28/06/2019'}
# {'invoice_id': '308140', 'quantity': 1, 'invoice_dtm': '03/10/2020'}
# {'invoice_id': '246289', 'quantity': 1, 'invoice_dtm': '29/05/2019'}
# {'invoice_id': '129797', 'quantity': 1, 'invoice_dtm': '28/06/2022'}
# {'invoice_id': '290106', 'quantity': 3, 'invoice_dtm': '12/09/2012'}
# {'invoice_id': '119804', 'quantity': 3, 'invoice_dtm': '09/04/2015'}
# {'invoice_id': '183207', 'quantity': 6, 'invoice_dtm': '25/01/2018'}
# {'invoice_id': '84615', 'quantity': 2, 'invoice_dtm': '18/04/2010'}
# {'invoice_id': '395670', 'quantity': 2, 'invoice_dtm': '12/10/2014'}
# {'invoice_id': '465116', 'quantity': 1, 'invoice_dtm': '22/12/2016'}
# {'invoice_id': '414298', 'quantity': 1, 'invoice_dtm': '24/01/2019'}
# {'invoice_id': '379086', 'quantity': 1, 'invoice_dtm': '02/07/2010'}
# {'invoice_id': '235097', 'quantity': 1, 'invoice_dtm': '13/11/2012'}
# {'invoice_id': '460560', 'quantity': 12, 'invoice_dtm': '29/12/2022'}
# {'invoice_id': '35929', 'quantity': 1, 'invoice_dtm': '07/10/2022'}
# {'invoice_id': '425953', 'quantity': 1, 'invoice_dtm': '15/09/2016'}
# {'invoice_id': '338369', 'quantity': 3, 'invoice_dtm': '15/01/2019'}
# {'invoice_id': '451960', 'quantity': 3, 'invoice_dtm': '27/08/2017'}
# {'invoice_id': '304306', 'quantity': 1, 'invoice_dtm': '27/05/2010'}
# {'invoice_id': '480436', 'quantity': 4, 'invoice_dtm': '20/11/2018'}
# {'invoice_id': '42594', 'quantity': 3, 'invoice_dtm': '29/09/2017'}
# {'invoice_id': '152398', 'quantity': 3, 'invoice_dtm': '06/09/2011'}
# {'invoice_id': '380777', 'quantity': 1, 'invoice_dtm': '26/12/2012'}
# {'invoice_id': '460074', 'quantity': 1, 'invoice_dtm': '18/02/2022'}
# {'invoice_id': '74145', 'quantity': 1, 'invoice_dtm': '29/10/2014'}
# {'invoice_id': '132630', 'quantity': 1, 'invoice_dtm': '31/01/2018'}
# {'invoice_id': '185658', 'quantity': 1, 'invoice_dtm': '29/07/2016'}
# {'invoice_id': '495246', 'quantity': 1, 'invoice_dtm': '15/03/2019'}
# {'invoice_id': '279634', 'quantity': 1, 'invoice_dtm': '02/11/2013'}
# {'invoice_id': '441911', 'quantity': 1, 'invoice_dtm': '13/05/2014'}
# {'invoice_id': '456206', 'quantity': 1, 'invoice_dtm': '08/10/2013'}
# {'invoice_id': '378605', 'quantity': 1, 'invoice_dtm': '25/04/2011'}
# {'invoice_id': '131197', 'quantity': 3, 'invoice_dtm': '19/12/2020'}
# {'invoice_id': '206872', 'quantity': 5, 'invoice_dtm': '22/10/2010'}
# {'invoice_id': '198618', 'quantity': 1, 'invoice_dtm': '23/06/2012'}
# {'invoice_id': '492751', 'quantity': 10, 'invoice_dtm': '18/10/2020'}
# {'invoice_id': '284892', 'quantity': 1, 'invoice_dtm': '07/12/2017'}
# {'invoice_id': '12254', 'quantity': 1, 'invoice_dtm': '23/11/2014'}
# {'invoice_id': '304833', 'quantity': 3, 'invoice_dtm': '26/03/2018'}
# {'invoice_id': '110617', 'quantity': 24, 'invoice_dtm': '27/01/2018'}
# {'invoice_id': '356570', 'quantity': 2, 'invoice_dtm': '17/10/2017'}
# {'invoice_id': '132439', 'quantity': 3, 'invoice_dtm': '27/12/2020'}
# {'invoice_id': '5018', 'quantity': 2, 'invoice_dtm': '31/01/2011'}
# {'invoice_id': '303484', 'quantity': 1, 'invoice_dtm': '02/04/2018'}
# {'invoice_id': '108491', 'quantity': 1, 'invoice_dtm': '05/06/2019'}
# {'invoice_id': '463482', 'quantity': 2, 'invoice_dtm': '28/09/2017'}
# {'invoice_id': '100900', 'quantity': 2, 'invoice_dtm': '24/06/2019'}
# {'invoice_id': '474939', 'quantity': 1, 'invoice_dtm': '07/03/2013'}
# {'invoice_id': '350212', 'quantity': 6, 'invoice_dtm': '22/01/2014'}
# {'invoice_id': '209758', 'quantity': 1, 'invoice_dtm': '04/06/2013'}
# {'invoice_id': '171337', 'quantity': 2, 'invoice_dtm': '21/10/2017'}
# {'invoice_id': '35927', 'quantity': 3, 'invoice_dtm': '18/07/2012'}
# {'invoice_id': '174608', 'quantity': 7, 'invoice_dtm': '06/02/2020'}
# {'invoice_id': '247419', 'quantity': 1, 'invoice_dtm': '01/03/2022'}
# {'invoice_id': '176037', 'quantity': 5, 'invoice_dtm': '12/07/2011'}
# {'invoice_id': '497692', 'quantity': 5, 'invoice_dtm': '27/07/2020'}
# {'invoice_id': '47579', 'quantity': 12, 'invoice_dtm': '11/08/2016'}
# {'invoice_id': '473314', 'quantity': 5, 'invoice_dtm': '02/01/2019'}
# {'invoice_id': '316328', 'quantity': 1, 'invoice_dtm': '05/01/2015'}
# {'invoice_id': '180579', 'quantity': 2, 'invoice_dtm': '24/06/2016'}
# {'invoice_id': '213179', 'quantity': 5, 'invoice_dtm': '01/08/2011'}
# {'invoice_id': '411144', 'quantity': 2, 'invoice_dtm': '23/05/2010'}
# {'invoice_id': '95442', 'quantity': 1, 'invoice_dtm': '11/05/2022'}
# {'invoice_id': '369115', 'quantity': 2, 'invoice_dtm': '06/12/2020'}
# {'invoice_id': '338380', 'quantity': 1, 'invoice_dtm': '01/05/2019'}
# {'invoice_id': '142367', 'quantity': 2, 'invoice_dtm': '01/11/2022'}
# {'invoice_id': '274441', 'quantity': 1, 'invoice_dtm': '27/03/2013'}
# {'invoice_id': '209038', 'quantity': 2, 'invoice_dtm': '22/05/2012'}
# {'invoice_id': '351814', 'quantity': 3, 'invoice_dtm': '18/08/2021'}
# {'invoice_id': '483014', 'quantity': 1, 'invoice_dtm': '24/09/2012'}
# {'invoice_id': '38811', 'quantity': 1, 'invoice_dtm': '09/08/2011'}
# {'invoice_id': '444021', 'quantity': 3, 'invoice_dtm': '07/08/2014'}
# {'invoice_id': '303835', 'quantity': 2, 'invoice_dtm': '06/11/2014'}
# {'invoice_id': '31063', 'quantity': 1, 'invoice_dtm': '21/04/2015'}
# {'invoice_id': '466168', 'quantity': 1, 'invoice_dtm': '24/11/2016'}
# {'invoice_id': '364702', 'quantity': 2, 'invoice_dtm': '18/07/2017'}
# {'invoice_id': '204381', 'quantity': 2, 'invoice_dtm': '27/04/2016'}
# {'invoice_id': '350329', 'quantity': 4, 'invoice_dtm': '02/09/2021'}
# {'invoice_id': '470037', 'quantity': 7, 'invoice_dtm': '30/09/2017'}
# {'invoice_id': '398202', 'quantity': 2, 'invoice_dtm': '17/07/2022'}
# {'invoice_id': '103197', 'quantity': 7, 'invoice_dtm': '13/08/2012'}
# {'invoice_id': '90350', 'quantity': 1, 'invoice_dtm': '17/05/2010'}
# {'invoice_id': '247992', 'quantity': 1, 'invoice_dtm': '28/12/2022'}
# {'invoice_id': '176244', 'quantity': 1, 'invoice_dtm': '27/12/2022'}
# {'invoice_id': '277446', 'quantity': 2, 'invoice_dtm': '08/10/2011'}
# {'invoice_id': '474842', 'quantity': 5, 'invoice_dtm': '19/01/2012'}
# {'invoice_id': '305039', 'quantity': 2, 'invoice_dtm': '12/12/2020'}
# {'invoice_id': '297907', 'quantity': 1, 'invoice_dtm': '06/02/2011'}
# {'invoice_id': '185651', 'quantity': 2, 'invoice_dtm': '22/01/2022'}
# {'invoice_id': '248844', 'quantity': 1, 'invoice_dtm': '02/10/2012'}
# {'invoice_id': '198832', 'quantity': 1, 'invoice_dtm': '21/02/2014'}
# {'invoice_id': '167688', 'quantity': 1, 'invoice_dtm': '02/09/2017'}
# {'invoice_id': '308335', 'quantity': 2, 'invoice_dtm': '06/11/2013'}
# {'invoice_id': '161420', 'quantity': 1, 'invoice_dtm': '09/06/2011'}
# {'invoice_id': '324514', 'quantity': 6, 'invoice_dtm': '06/10/2010'}
# {'invoice_id': '465837', 'quantity': 1, 'invoice_dtm': '25/12/2010'}
# {'invoice_id': '266080', 'quantity': 1, 'invoice_dtm': '16/08/2018'}
# {'invoice_id': '458683', 'quantity': 56, 'invoice_dtm': '27/01/2021'}
# {'invoice_id': '23579', 'quantity': 10, 'invoice_dtm': '22/06/2017'}
# {'invoice_id': '326665', 'quantity': 5, 'invoice_dtm': '24/11/2015'}
# {'invoice_id': '167573', 'quantity': 3, 'invoice_dtm': '01/08/2021'}
# {'invoice_id': '216942', 'quantity': 3, 'invoice_dtm': '01/04/2017'}
# {'invoice_id': '341010', 'quantity': 3, 'invoice_dtm': '08/03/2012'}
# {'invoice_id': '56650', 'quantity': 5, 'invoice_dtm': '28/07/2018'}
# {'invoice_id': '145661', 'quantity': 2, 'invoice_dtm': '18/01/2018'}
# {'invoice_id': '472031', 'quantity': 5, 'invoice_dtm': '05/04/2013'}
# {'invoice_id': '205359', 'quantity': 3, 'invoice_dtm': '22/09/2019'}
# {'invoice_id': '398166', 'quantity': 1, 'invoice_dtm': '15/05/2019'}
# {'invoice_id': '160629', 'quantity': 1, 'invoice_dtm': '17/01/2019'}
# {'invoice_id': '368155', 'quantity': 5, 'invoice_dtm': '02/08/2016'}
# {'invoice_id': '110514', 'quantity': 4, 'invoice_dtm': '17/05/2017'}
# {'invoice_id': '207432', 'quantity': 6, 'invoice_dtm': '23/12/2019'}
# {'invoice_id': '412426', 'quantity': 3, 'invoice_dtm': '29/12/2019'}
# {'invoice_id': '418392', 'quantity': 5, 'invoice_dtm': '24/11/2011'}
# {'invoice_id': '216774', 'quantity': 3, 'invoice_dtm': '21/06/2021'}
# {'invoice_id': '199332', 'quantity': 4, 'invoice_dtm': '10/11/2016'}
# {'invoice_id': '180065', 'quantity': 3, 'invoice_dtm': '09/10/2021'}
# {'invoice_id': '433404', 'quantity': 3, 'invoice_dtm': '18/03/2022'}
# {'invoice_id': '126390', 'quantity': 12, 'invoice_dtm': '25/04/2015'}
# {'invoice_id': '76445', 'quantity': 5, 'invoice_dtm': '22/09/2014'}
# {'invoice_id': '95009', 'quantity': 4, 'invoice_dtm': '16/07/2013'}
# {'invoice_id': '54444', 'quantity': 6, 'invoice_dtm': '13/01/2021'}
# {'invoice_id': '418396', 'quantity': 12, 'invoice_dtm': '06/07/2017'}
# {'invoice_id': '467336', 'quantity': 2, 'invoice_dtm': '19/10/2015'}
# {'invoice_id': '118411', 'quantity': 12, 'invoice_dtm': '25/11/2011'}
# {'invoice_id': '358035', 'quantity': 1, 'invoice_dtm': '14/11/2019'}
# {'invoice_id': '381210', 'quantity': 2, 'invoice_dtm': '23/10/2017'}
# {'invoice_id': '447559', 'quantity': 3, 'invoice_dtm': '07/01/2010'}
# {'invoice_id': '267489', 'quantity': 3, 'invoice_dtm': '06/07/2021'}
# {'invoice_id': '496186', 'quantity': 3, 'invoice_dtm': '19/09/2014'}
# {'invoice_id': '101233', 'quantity': 6, 'invoice_dtm': '28/04/2021'}
# {'invoice_id': '351341', 'quantity': 2, 'invoice_dtm': '02/11/2020'}
# {'invoice_id': '19666', 'quantity': 2, 'invoice_dtm': '11/02/2015'}
# {'invoice_id': '278444', 'quantity': 2, 'invoice_dtm': '10/06/2021'}
# {'invoice_id': '88418', 'quantity': 2, 'invoice_dtm': '28/10/2015'}
# {'invoice_id': '384389', 'quantity': 3, 'invoice_dtm': '06/05/2020'}
# {'invoice_id': '295603', 'quantity': 3, 'invoice_dtm': '25/06/2010'}
# {'invoice_id': '189747', 'quantity': 3, 'invoice_dtm': '20/12/2016'}
# {'invoice_id': '279824', 'quantity': 3, 'invoice_dtm': '15/04/2010'}
# {'invoice_id': '162754', 'quantity': 3, 'invoice_dtm': '06/07/2014'}
# {'invoice_id': '147671', 'quantity': 2, 'invoice_dtm': '08/09/2019'}
# {'invoice_id': '149269', 'quantity': 4, 'invoice_dtm': '26/02/2022'}
# {'invoice_id': '118707', 'quantity': 3, 'invoice_dtm': '09/11/2019'}
# {'invoice_id': '6195', 'quantity': 3, 'invoice_dtm': '20/11/2017'}
# {'invoice_id': '484013', 'quantity': 2, 'invoice_dtm': '14/12/2021'}
# {'invoice_id': '444311', 'quantity': 3, 'invoice_dtm': '27/02/2011'}
# {'invoice_id': '472967', 'quantity': 3, 'invoice_dtm': '22/09/2017'}
# {'invoice_id': '102362', 'quantity': 3, 'invoice_dtm': '01/06/2018'}
# {'invoice_id': '188211', 'quantity': 3, 'invoice_dtm': '22/12/2019'}
# {'invoice_id': '140231', 'quantity': 3, 'invoice_dtm': '08/07/2013'}
# {'invoice_id': '216234', 'quantity': 3, 'invoice_dtm': '06/05/2021'}
# {'invoice_id': '169012', 'quantity': 3, 'invoice_dtm': '02/09/2011'}
# {'invoice_id': '394285', 'quantity': 3, 'invoice_dtm': '27/09/2021'}
# {'invoice_id': '1099', 'quantity': 3, 'invoice_dtm': '18/10/2019'}
# {'invoice_id': '193827', 'quantity': 2, 'invoice_dtm': '26/06/2013'}
# {'invoice_id': '360928', 'quantity': 2, 'invoice_dtm': '07/03/2010'}
# {'invoice_id': '86694', 'quantity': 12, 'invoice_dtm': '31/05/2018'}
# {'invoice_id': '368317', 'quantity': 12, 'invoice_dtm': '25/01/2020'}
# {'invoice_id': '332650', 'quantity': 72, 'invoice_dtm': '12/02/2018'}
# {'invoice_id': '159269', 'quantity': 12, 'invoice_dtm': '07/03/2012'}
# {'invoice_id': '265732', 'quantity': 4, 'invoice_dtm': '16/05/2019'}
# {'invoice_id': '301887', 'quantity': 4, 'invoice_dtm': '21/05/2012'}
# {'invoice_id': '73359', 'quantity': 6, 'invoice_dtm': '21/04/2013'}
# {'invoice_id': '157211', 'quantity': 12, 'invoice_dtm': '03/07/2020'}
# {'invoice_id': '157068', 'quantity': 12, 'invoice_dtm': '11/01/2020'}
# {'invoice_id': '56716', 'quantity': 12, 'invoice_dtm': '25/02/2011'}
# {'invoice_id': '226038', 'quantity': 6, 'invoice_dtm': '15/08/2013'}
# {'invoice_id': '458328', 'quantity': 12, 'invoice_dtm': '03/09/2015'}
# ...
# {'invoice_id': '311039', 'quantity': 12, 'invoice_dtm': '03/06/2019'}
# {'invoice_id': '451438', 'quantity': 24, 'invoice_dtm': '25/01/2020'}
# {'invoice_id': '174957', 'quantity': 24, 'invoice_dtm': '14/09/2021'}
# {'invoice_id': '335398', 'quantity': 12, 'invoice_dtm': '15/12/2014'}
# {'invoice_id': '329429', 'quantity': 2, 'invoice_dtm': '02/04/2020'}
# {'invoice_id': '51628', 'quantity': 4, 'invoice_dtm': '02/08/2018'}
# {'invoice_id': '455161', 'quantity': 2, 'invoice_dtm': '17/09/2020'}
# {'invoice_id': '229548', 'quantity': 24, 'invoice_dtm': '04/01/2013'}
# {'invoice_id': '10265', 'quantity': 6, 'invoice_dtm': '20/10/2016'}
# {'invoice_id': '367193', 'quantity': 8, 'invoice_dtm': '09/07/2017'}
# {'invoice_id': '168102', 'quantity': 2, 'invoice_dtm': '09/07/2013'}
# {'invoice_id': '314437', 'quantity': 2, 'invoice_dtm': '15/03/2013'}
# {'invoice_id': '140406', 'quantity': 24, 'invoice_dtm': '15/02/2015'}
# {'invoice_id': '445266', 'quantity': 12, 'invoice_dtm': '07/11/2018'}
# {'invoice_id': '95825', 'quantity': 2, 'invoice_dtm': '02/09/2012'}
# {'invoice_id': '454924', 'quantity': 2, 'invoice_dtm': '05/04/2010'}
# {'invoice_id': '114051', 'quantity': 2, 'invoice_dtm': '14/02/2017'}
# {'invoice_id': '299517', 'quantity': 3, 'invoice_dtm': '28/08/2016'}
# {'invoice_id': '224020', 'quantity': 1, 'invoice_dtm': '07/08/2013'}
# {'invoice_id': '468829', 'quantity': 1, 'invoice_dtm': '09/03/2019'}
# {'invoice_id': '320019', 'quantity': 3, 'invoice_dtm': '26/07/2018'}
# {'invoice_id': '404109', 'quantity': 1, 'invoice_dtm': '09/09/2014'}
# {'invoice_id': '237648', 'quantity': 1, 'invoice_dtm': '22/01/2013'}
# {'invoice_id': '86864', 'quantity': 1, 'invoice_dtm': '12/07/2013'}
# {'invoice_id': '427438', 'quantity': 8, 'invoice_dtm': '26/12/2014'}
# {'invoice_id': '68311', 'quantity': 1, 'invoice_dtm': '19/05/2015'}
# {'invoice_id': '307908', 'quantity': 1, 'invoice_dtm': '07/07/2014'}
# {'invoice_id': '47819', 'quantity': 1, 'invoice_dtm': '27/03/2021'}
# {'invoice_id': '162877', 'quantity': 2, 'invoice_dtm': '05/12/2013'}
# {'invoice_id': '289673', 'quantity': 1, 'invoice_dtm': '27/03/2014'}
# {'invoice_id': '459789', 'quantity': 1, 'invoice_dtm': '23/02/2015'}
# {'invoice_id': '224776', 'quantity': 1, 'invoice_dtm': '19/09/2022'}
# {'invoice_id': '19932', 'quantity': 1, 'invoice_dtm': '21/02/2013'}
# {'invoice_id': '9064', 'quantity': 1, 'invoice_dtm': '23/07/2017'}
# {'invoice_id': '392341', 'quantity': 1, 'invoice_dtm': '20/08/2022'}
# {'invoice_id': '197058', 'quantity': 2, 'invoice_dtm': '18/06/2022'}
# {'invoice_id': '10058', 'quantity': 6, 'invoice_dtm': '04/05/2013'}
# {'invoice_id': '185206', 'quantity': 5, 'invoice_dtm': '14/07/2016'}
# {'invoice_id': '311215', 'quantity': 1, 'invoice_dtm': '25/09/2017'}
# {'invoice_id': '56506', 'quantity': 1, 'invoice_dtm': '21/06/2022'}
# {'invoice_id': '124445', 'quantity': 1, 'invoice_dtm': '23/04/2017'}
# {'invoice_id': '143722', 'quantity': 1, 'invoice_dtm': '14/09/2021'}
# {'invoice_id': '333698', 'quantity': 1, 'invoice_dtm': '01/05/2019'}
# {'invoice_id': '465658', 'quantity': 1, 'invoice_dtm': '11/03/2019'}
# {'invoice_id': '301498', 'quantity': 2, 'invoice_dtm': '13/12/2012'}
# {'invoice_id': '398537', 'quantity': 2, 'invoice_dtm': '27/01/2018'}
# {'invoice_id': '440045', 'quantity': 6, 'invoice_dtm': '08/05/2012'}
# {'invoice_id': '381350', 'quantity': 2, 'invoice_dtm': '01/09/2018'}
# {'invoice_id': '402825', 'quantity': 4, 'invoice_dtm': '02/05/2021'}
# {'invoice_id': '304547', 'quantity': 2, 'invoice_dtm': '23/01/2019'}
# {'invoice_id': '332530', 'quantity': 2, 'invoice_dtm': '13/08/2017'}
# {'invoice_id': '96624', 'quantity': 1, 'invoice_dtm': '30/08/2014'}
# {'invoice_id': '3366', 'quantity': 1, 'invoice_dtm': '28/06/2018'}
# {'invoice_id': '383730', 'quantity': 1, 'invoice_dtm': '08/02/2013'}
# {'invoice_id': '96744', 'quantity': 2, 'invoice_dtm': '26/07/2012'}
# {'invoice_id': '152401', 'quantity': 1, 'invoice_dtm': '09/09/2021'}
# {'invoice_id': '269641', 'quantity': 1, 'invoice_dtm': '15/01/2014'}
# {'invoice_id': '24327', 'quantity': 1, 'invoice_dtm': '18/04/2010'}
# {'invoice_id': '106096', 'quantity': 1, 'invoice_dtm': '12/12/2015'}
# {'invoice_id': '396138', 'quantity': 1, 'invoice_dtm': '08/10/2014'}
# {'invoice_id': '94844', 'quantity': 1, 'invoice_dtm': '09/03/2010'}
# {'invoice_id': '398406', 'quantity': 1, 'invoice_dtm': '30/08/2013'}
# {'invoice_id': '277726', 'quantity': 1, 'invoice_dtm': '03/04/2010'}
# {'invoice_id': '229713', 'quantity': 2, 'invoice_dtm': '02/11/2020'}
# {'invoice_id': '169124', 'quantity': 1, 'invoice_dtm': '24/03/2013'}
# {'invoice_id': '419095', 'quantity': 3, 'invoice_dtm': '05/06/2015'}
# {'invoice_id': '335508', 'quantity': 2, 'invoice_dtm': '14/03/2013'}
# {'invoice_id': '230413', 'quantity': 1, 'invoice_dtm': '26/10/2015'}
# {'invoice_id': '30149', 'quantity': 6, 'invoice_dtm': '31/07/2015'}
# {'invoice_id': '403724', 'quantity': 1, 'invoice_dtm': '08/03/2012'}
# {'invoice_id': '495763', 'quantity': 1, 'invoice_dtm': '06/06/2012'}
# {'invoice_id': '64858', 'quantity': 2, 'invoice_dtm': '16/08/2013'}
# {'invoice_id': '73493', 'quantity': 3, 'invoice_dtm': '19/10/2020'}
# {'invoice_id': '131837', 'quantity': 1, 'invoice_dtm': '08/02/2012'}
# {'invoice_id': '212966', 'quantity': 1, 'invoice_dtm': '01/08/2022'}
# {'invoice_id': '426235', 'quantity': 1, 'invoice_dtm': '26/03/2016'}
# {'invoice_id': '111875', 'quantity': 1, 'invoice_dtm': '23/06/2015'}
# {'invoice_id': '298718', 'quantity': 3, 'invoice_dtm': '31/01/2018'}
# {'invoice_id': '204969', 'quantity': 5, 'invoice_dtm': '16/05/2012'}
# {'invoice_id': '377775', 'quantity': 5, 'invoice_dtm': '02/02/2018'}
# {'invoice_id': '489226', 'quantity': 2, 'invoice_dtm': '29/10/2018'}
# {'invoice_id': '29287', 'quantity': 1, 'invoice_dtm': '03/08/2017'}
# {'invoice_id': '190055', 'quantity': 1, 'invoice_dtm': '04/06/2020'}
# {'invoice_id': '188506', 'quantity': 1, 'invoice_dtm': '24/09/2013'}
# {'invoice_id': '253779', 'quantity': 1, 'invoice_dtm': '14/04/2013'}
# {'invoice_id': '5845', 'quantity': 1, 'invoice_dtm': '14/11/2011'}
# {'invoice_id': '245569', 'quantity': 1, 'invoice_dtm': '23/08/2014'}
# {'invoice_id': '12469', 'quantity': 1, 'invoice_dtm': '02/07/2021'}
# {'invoice_id': '280303', 'quantity': 1, 'invoice_dtm': '28/01/2022'}
# {'invoice_id': '237964', 'quantity': 1, 'invoice_dtm': '16/11/2018'}
# {'invoice_id': '79873', 'quantity': 1, 'invoice_dtm': '22/05/2011'}
# {'invoice_id': '63126', 'quantity': 2, 'invoice_dtm': '12/10/2012'}
# {'invoice_id': '130721', 'quantity': 1, 'invoice_dtm': '19/06/2013'}
# {'invoice_id': '425398', 'quantity': 1, 'invoice_dtm': '11/12/2017'}
# {'invoice_id': '138452', 'quantity': 8, 'invoice_dtm': '08/09/2012'}
# {'invoice_id': '182959', 'quantity': 1, 'invoice_dtm': '18/12/2014'}
# {'invoice_id': '281910', 'quantity': 1, 'invoice_dtm': '26/02/2021'}
# {'invoice_id': '200160', 'quantity': 6, 'invoice_dtm': '28/07/2020'}
# {'invoice_id': '401972', 'quantity': 1, 'invoice_dtm': '03/05/2022'}
# {'invoice_id': '87333', 'quantity': 6, 'invoice_dtm': '04/11/2015'}
# {'invoice_id': '317363', 'quantity': 12, 'invoice_dtm': '07/11/2021'}
# {'invoice_id': '284397', 'quantity': 48, 'invoice_dtm': '16/07/2015'}
# {'invoice_id': '439405', 'quantity': 24, 'invoice_dtm': '09/01/2015'}
# {'invoice_id': '481765', 'quantity': 480, 'invoice_dtm': '14/06/2013'}
# {'invoice_id': '197723', 'quantity': 48, 'invoice_dtm': '04/11/2017'}
# {'invoice_id': '199447', 'quantity': 16, 'invoice_dtm': '21/03/2012'}
# {'invoice_id': '67230', 'quantity': 16, 'invoice_dtm': '25/05/2013'}
# {'invoice_id': '332322', 'quantity': 4, 'invoice_dtm': '02/06/2013'}
# {'invoice_id': '161848', 'quantity': 96, 'invoice_dtm': '22/03/2011'}
# {'invoice_id': '497039', 'quantity': 144, 'invoice_dtm': '03/12/2021'}
# {'invoice_id': '258349', 'quantity': 144, 'invoice_dtm': '18/06/2011'}
# {'invoice_id': '278843', 'quantity': 12, 'invoice_dtm': '20/10/2014'}
# {'invoice_id': '458820', 'quantity': 12, 'invoice_dtm': '22/11/2015'}
# {'invoice_id': '284479', 'quantity': 16, 'invoice_dtm': '27/01/2020'}
# {'invoice_id': '465752', 'quantity': 10, 'invoice_dtm': '24/04/2012'}
# {'invoice_id': '60863', 'quantity': 5, 'invoice_dtm': '25/11/2021'}
# {'invoice_id': '448324', 'quantity': 1, 'invoice_dtm': '15/04/2017'}
# {'invoice_id': '364495', 'quantity': 8, 'invoice_dtm': '23/06/2015'}
# {'invoice_id': '384492', 'quantity': 5, 'invoice_dtm': '04/08/2020'}
# {'invoice_id': '142517', 'quantity': 1, 'invoice_dtm': '01/04/2022'}
# {'invoice_id': '442696', 'quantity': 1, 'invoice_dtm': '09/10/2021'}
# {'invoice_id': '304062', 'quantity': 1, 'invoice_dtm': '05/08/2011'}
# {'invoice_id': '276731', 'quantity': 2, 'invoice_dtm': '15/08/2011'}
# {'invoice_id': '372479', 'quantity': 1, 'invoice_dtm': '19/12/2016'}
# {'invoice_id': '490479', 'quantity': 1, 'invoice_dtm': '27/09/2017'}
# {'invoice_id': '323283', 'quantity': 1, 'invoice_dtm': '14/10/2019'}
# {'invoice_id': '444017', 'quantity': 1, 'invoice_dtm': '20/01/2022'}
# {'invoice_id': '50040', 'quantity': 1, 'invoice_dtm': '20/08/2019'}
# {'invoice_id': '158147', 'quantity': 2, 'invoice_dtm': '02/12/2014'}
# {'invoice_id': '440184', 'quantity': 12, 'invoice_dtm': '05/04/2015'}
# {'invoice_id': '7331', 'quantity': 1, 'invoice_dtm': '16/12/2011'}
# {'invoice_id': '266107', 'quantity': 2, 'invoice_dtm': '17/10/2019'}
# {'invoice_id': '219252', 'quantity': 1, 'invoice_dtm': '10/07/2022'}
# {'invoice_id': '339337', 'quantity': 1, 'invoice_dtm': '04/03/2018'}
# {'invoice_id': '134929', 'quantity': 1, 'invoice_dtm': '31/01/2021'}
# {'invoice_id': '476692', 'quantity': 1, 'invoice_dtm': '29/03/2019'}
# {'invoice_id': '25518', 'quantity': 1, 'invoice_dtm': '29/05/2016'}
# {'invoice_id': '484456', 'quantity': 1, 'invoice_dtm': '13/11/2018'}
# {'invoice_id': '39053', 'quantity': 1, 'invoice_dtm': '28/04/2019'}
# {'invoice_id': '333632', 'quantity': 1, 'invoice_dtm': '26/04/2022'}
# {'invoice_id': '169835', 'quantity': 1, 'invoice_dtm': '07/09/2014'}
# {'invoice_id': '417326', 'quantity': 1, 'invoice_dtm': '20/12/2017'}
# {'invoice_id': '154188', 'quantity': 3, 'invoice_dtm': '18/03/2016'}
# {'invoice_id': '251700', 'quantity': 3, 'invoice_dtm': '22/06/2013'}
# {'invoice_id': '433748', 'quantity': 1, 'invoice_dtm': '30/09/2011'}
# {'invoice_id': '391724', 'quantity': 1, 'invoice_dtm': '27/12/2022'}
# {'invoice_id': '181846', 'quantity': 3, 'invoice_dtm': '30/12/2015'}
# {'invoice_id': '309539', 'quantity': 1, 'invoice_dtm': '22/08/2022'}
# {'invoice_id': '314710', 'quantity': 2, 'invoice_dtm': '18/10/2020'}
# {'invoice_id': '477377', 'quantity': 2, 'invoice_dtm': '17/03/2015'}
# {'invoice_id': '112397', 'quantity': 10, 'invoice_dtm': '05/10/2019'}
# {'invoice_id': '361934', 'quantity': 10, 'invoice_dtm': '10/04/2010'}
# {'invoice_id': '229777', 'quantity': 2, 'invoice_dtm': '22/06/2013'}
# {'invoice_id': '127472', 'quantity': 12, 'invoice_dtm': '31/07/2015'}
# {'invoice_id': '350615', 'quantity': 12, 'invoice_dtm': '26/09/2019'}
# {'invoice_id': '303051', 'quantity': 12, 'invoice_dtm': '13/05/2012'}
# {'invoice_id': '139634', 'quantity': 12, 'invoice_dtm': '16/06/2010'}
# {'invoice_id': '13901', 'quantity': 3, 'invoice_dtm': '10/11/2017'}
# {'invoice_id': '246590', 'quantity': 2, 'invoice_dtm': '17/03/2010'}
# {'invoice_id': '31825', 'quantity': 2, 'invoice_dtm': '16/08/2011'}
# {'invoice_id': '152181', 'quantity': 7, 'invoice_dtm': '07/12/2018'}
# {'invoice_id': '369666', 'quantity': 3, 'invoice_dtm': '19/10/2017'}
# {'invoice_id': '427632', 'quantity': 3, 'invoice_dtm': '25/12/2011'}
# {'invoice_id': '83079', 'quantity': 6, 'invoice_dtm': '05/07/2011'}
# {'invoice_id': '126593', 'quantity': 6, 'invoice_dtm': '31/05/2018'}
# {'invoice_id': '91473', 'quantity': 16, 'invoice_dtm': '24/10/2017'}
# {'invoice_id': '376778', 'quantity': 3, 'invoice_dtm': '20/06/2012'}
# {'invoice_id': '194040', 'quantity': 12, 'invoice_dtm': '03/03/2013'}
# {'invoice_id': '72298', 'quantity': 6, 'invoice_dtm': '02/11/2021'}
# {'invoice_id': '441807', 'quantity': 2, 'invoice_dtm': '18/01/2020'}
# {'invoice_id': '424305', 'quantity': 72, 'invoice_dtm': '17/04/2021'}
# {'invoice_id': '109859', 'quantity': 144, 'invoice_dtm': '14/03/2011'}
# {'invoice_id': '124620', 'quantity': -6, 'invoice_dtm': '24/08/2019'}
# {'invoice_id': '27957', 'quantity': 36, 'invoice_dtm': '18/11/2018'}
# {'invoice_id': '108882', 'quantity': 4, 'invoice_dtm': '04/10/2013'}
# {'invoice_id': '207163', 'quantity': 6, 'invoice_dtm': '20/10/2013'}
# {'invoice_id': '367218', 'quantity': 36, 'invoice_dtm': '14/09/2020'}
# {'invoice_id': '75840', 'quantity': 36, 'invoice_dtm': '20/10/2021'}
# {'invoice_id': '370112', 'quantity': 1, 'invoice_dtm': '03/04/2018'}
# {'invoice_id': '20664', 'quantity': 1, 'invoice_dtm': '03/04/2017'}
# {'invoice_id': '198323', 'quantity': 1, 'invoice_dtm': '13/09/2015'}
# {'invoice_id': '218764', 'quantity': 1, 'invoice_dtm': '14/10/2015'}
# {'invoice_id': '405150', 'quantity': 2, 'invoice_dtm': '23/05/2011'}
# {'invoice_id': '140817', 'quantity': 16, 'invoice_dtm': '19/02/2011'}
# {'invoice_id': '354018', 'quantity': 1, 'invoice_dtm': '21/08/2011'}
# {'invoice_id': '58247', 'quantity': 4, 'invoice_dtm': '05/03/2017'}
# {'invoice_id': '30559', 'quantity': 3, 'invoice_dtm': '04/02/2022'}
# {'invoice_id': '314834', 'quantity': 1, 'invoice_dtm': '29/08/2010'}
# {'invoice_id': '189331', 'quantity': 1, 'invoice_dtm': '17/08/2020'}
# {'invoice_id': '334959', 'quantity': 1, 'invoice_dtm': '12/11/2010'}
# {'invoice_id': '477680', 'quantity': 2, 'invoice_dtm': '31/03/2021'}
# {'invoice_id': '366012', 'quantity': 1, 'invoice_dtm': '20/12/2020'}
# {'invoice_id': '211584', 'quantity': 1, 'invoice_dtm': '24/04/2012'}
# {'invoice_id': '160065', 'quantity': 14, 'invoice_dtm': '08/11/2020'}
# {'invoice_id': '54742', 'quantity': 4, 'invoice_dtm': '17/07/2021'}
# {'invoice_id': '71052', 'quantity': 4, 'invoice_dtm': '21/08/2015'}
# {'invoice_id': '386485', 'quantity': 3, 'invoice_dtm': '29/04/2013'}
# {'invoice_id': '128964', 'quantity': 2, 'invoice_dtm': '21/02/2011'}
# {'invoice_id': '1384', 'quantity': 1, 'invoice_dtm': '08/04/2018'}
# {'invoice_id': '16997', 'quantity': 1, 'invoice_dtm': '02/05/2022'}
# {'invoice_id': '386815', 'quantity': 1, 'invoice_dtm': '10/12/2021'}
# {'invoice_id': '138173', 'quantity': 2, 'invoice_dtm': '16/02/2014'}
# {'invoice_id': '485754', 'quantity': 6, 'invoice_dtm': '23/06/2014'}
# {'invoice_id': '152913', 'quantity': 1, 'invoice_dtm': '17/04/2016'}
# {'invoice_id': '440862', 'quantity': 5, 'invoice_dtm': '29/04/2019'}
# {'invoice_id': '404200', 'quantity': 3, 'invoice_dtm': '24/09/2015'}
# {'invoice_id': '356000', 'quantity': 2, 'invoice_dtm': '27/02/2011'}
# {'invoice_id': '284708', 'quantity': 1, 'invoice_dtm': '02/11/2015'}
# {'invoice_id': '41141', 'quantity': 3, 'invoice_dtm': '21/12/2021'}
# {'invoice_id': '230706', 'quantity': 2, 'invoice_dtm': '17/07/2021'}
# {'invoice_id': '246902', 'quantity': 2, 'invoice_dtm': '30/01/2014'}
# {'invoice_id': '416177', 'quantity': 1, 'invoice_dtm': '13/07/2016'}
# {'invoice_id': '155300', 'quantity': 3, 'invoice_dtm': '06/04/2011'}
# {'invoice_id': '15261', 'quantity': 1, 'invoice_dtm': '30/04/2013'}
# {'invoice_id': '125874', 'quantity': 3, 'invoice_dtm': '18/08/2022'}
# {'invoice_id': '171369', 'quantity': 12, 'invoice_dtm': '22/11/2018'}
# {'invoice_id': '350905', 'quantity': 3, 'invoice_dtm': '14/11/2016'}
# {'invoice_id': '408386', 'quantity': 12, 'invoice_dtm': '03/03/2016'}
# {'invoice_id': '275123', 'quantity': 1, 'invoice_dtm': '22/03/2016'}
# {'invoice_id': '455752', 'quantity': 2, 'invoice_dtm': '17/06/2010'}
# {'invoice_id': '53885', 'quantity': 2, 'invoice_dtm': '19/05/2010'}
# {'invoice_id': '456474', 'quantity': 2, 'invoice_dtm': '01/10/2014'}
# {'invoice_id': '345890', 'quantity': 3, 'invoice_dtm': '30/08/2022'}
# {'invoice_id': '267082', 'quantity': 2, 'invoice_dtm': '17/10/2011'}
# {'invoice_id': '59604', 'quantity': 3, 'invoice_dtm': '11/06/2017'}
# {'invoice_id': '481341', 'quantity': 2, 'invoice_dtm': '03/11/2012'}
# {'invoice_id': '323116', 'quantity': 3, 'invoice_dtm': '10/02/2015'}
# {'invoice_id': '410416', 'quantity': 1, 'invoice_dtm': '24/06/2017'}
# {'invoice_id': '294939', 'quantity': 1, 'invoice_dtm': '09/07/2010'}
# {'invoice_id': '472966', 'quantity': 1, 'invoice_dtm': '17/05/2010'}
# {'invoice_id': '388953', 'quantity': 1, 'invoice_dtm': '02/03/2012'}
# {'invoice_id': '118034', 'quantity': 1, 'invoice_dtm': '05/09/2013'}

# %%
pd.DataFrame(transformed_data)
# Out:
#     invoice_id  quantity invoice_dtm
# 0       358640         6  03/01/2015
# 1       386946         6  07/03/2010
# 2       378650         8  05/05/2014
# 3        70847         6  18/05/2021
# 4       127544         6  22/10/2013
# ..         ...       ...         ...
# 994     410416         1  24/06/2017
# 995     294939         1  09/07/2010
# 996     472966         1  17/05/2010
# 997     388953         1  02/03/2012
# 998     118034         1  05/09/2013
#
# [999 rows x 3 columns]
